# %%
import gymnasium as gym
from stable_baselines3 import PPO

# Create the environment
env = gym.make("CartPole-v1")

# Initialize the PPO agent
model = PPO("MlpPolicy", env, verbose=1)

# Train the agent
model.learn(total_timesteps=10000)

# Save the model
model.save("ppo_cartpole")

# Test the trained agent
obs, _ = env.reset()
for _ in range(1000):
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        obs, _ = env.reset()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | 21.9     |
# | time/              |          |
# |    fps             | 2037     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.1         |
# |    ep_rew_mean          | 26.1         |
# | time/                   |              |
# |    fps                  | 1338         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0084158555 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.685       |
# |    explained_variance   | -0.00616     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7            |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0198      |
# |    value_loss           | 51.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.5        |
# |    ep_rew_mean          | 38.5        |
# | time/                   |             |
# |    fps                  | 1102        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009014522 |
# |    clip_fraction        | 0.064       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.0604      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 37.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.2        |
# |    ep_rew_mean          | 46.2        |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007643385 |
# |    clip_fraction        | 0.0736      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.641      |
# |    explained_variance   | 0.216       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 52.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62          |
# |    ep_rew_mean          | 62          |
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008317718 |
# |    clip_fraction        | 0.085       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.608      |
# |    explained_variance   | 0.342       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 59.3        |
# -----------------------------------------

# %%
model.learn(total_timesteps=50000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 169      |
# |    ep_rew_mean     | 169      |
# | time/              |          |
# |    fps             | 1342     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 195          |
# |    ep_rew_mean          | 195          |
# | time/                   |              |
# |    fps                  | 983          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0076084775 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.58        |
# |    explained_variance   | 0.44         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.2         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00939     |
# |    value_loss           | 65.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 214         |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 886         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006490537 |
# |    clip_fraction        | 0.0904      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.586      |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.4        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 49.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 243          |
# | time/                   |              |
# |    fps                  | 838          |
# |    iterations           | 4            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0033910892 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.559       |
# |    explained_variance   | 0.175        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.5         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00663     |
# |    value_loss           | 74.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 268          |
# |    ep_rew_mean          | 268          |
# | time/                   |              |
# |    fps                  | 806          |
# |    iterations           | 5            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0034021176 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.548       |
# |    explained_variance   | 0.615        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.8         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00497     |
# |    value_loss           | 54           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 270         |
# |    ep_rew_mean          | 270         |
# | time/                   |             |
# |    fps                  | 791         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006052127 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.534      |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.7        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00288    |
# |    value_loss           | 19.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 277         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007474789 |
# |    clip_fraction        | 0.0893      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.552      |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.71        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0097     |
# |    value_loss           | 16.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | 297         |
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 8           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006124885 |
# |    clip_fraction        | 0.0358      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.54       |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.64        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00629    |
# |    value_loss           | 46.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 311          |
# |    ep_rew_mean          | 311          |
# | time/                   |              |
# |    fps                  | 802          |
# |    iterations           | 9            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0037972932 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.535       |
# |    explained_variance   | 0.852        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.619        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00863     |
# |    value_loss           | 5.06         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 323         |
# |    ep_rew_mean          | 323         |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 10          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008991873 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.532      |
# |    explained_variance   | 0.359       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.166       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00206    |
# |    value_loss           | 2.27        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 333          |
# |    ep_rew_mean          | 333          |
# | time/                   |              |
# |    fps                  | 806          |
# |    iterations           | 11           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0021547182 |
# |    clip_fraction        | 0.00962      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.519       |
# |    explained_variance   | 0.0711       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.159        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -1.72e-05    |
# |    value_loss           | 1.51         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 343          |
# |    ep_rew_mean          | 343          |
# | time/                   |              |
# |    fps                  | 780          |
# |    iterations           | 12           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0073684864 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.518       |
# |    explained_variance   | 0.0198       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.101        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 0.957        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 351          |
# |    ep_rew_mean          | 351          |
# | time/                   |              |
# |    fps                  | 776          |
# |    iterations           | 13           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0053226543 |
# |    clip_fraction        | 0.0528       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.516       |
# |    explained_variance   | 0.834        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0368       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00913     |
# |    value_loss           | 0.575        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 359          |
# |    ep_rew_mean          | 359          |
# | time/                   |              |
# |    fps                  | 774          |
# |    iterations           | 14           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0023259425 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.528       |
# |    explained_variance   | 0.0344       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.034        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 0.371        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 366          |
# |    ep_rew_mean          | 366          |
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 15           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0036391462 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.533       |
# |    explained_variance   | 0.00965      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0331       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000958    |
# |    value_loss           | 0.237        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 372          |
# |    ep_rew_mean          | 372          |
# | time/                   |              |
# |    fps                  | 772          |
# |    iterations           | 16           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0048700077 |
# |    clip_fraction        | 0.0584       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.533       |
# |    explained_variance   | 0.0014       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0112       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 0.139        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 377         |
# |    ep_rew_mean          | 377         |
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 17          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.001869131 |
# |    clip_fraction        | 0.00693     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.528      |
# |    explained_variance   | 0.00463     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0203      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.000121    |
# |    value_loss           | 0.0883      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 384         |
# |    ep_rew_mean          | 384         |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 18          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005529199 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.535      |
# |    explained_variance   | 0.066       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00456    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00147    |
# |    value_loss           | 0.0574      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 388         |
# |    ep_rew_mean          | 388         |
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 19          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004210312 |
# |    clip_fraction        | 0.0248      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.544      |
# |    explained_variance   | -0.0138     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0232      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 0.0383      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 402         |
# |    ep_rew_mean          | 402         |
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 20          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006573536 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | -0.025      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00391    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00176    |
# |    value_loss           | 0.0239      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 415         |
# |    ep_rew_mean          | 415         |
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 21          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008794794 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.519      |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00852    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 0.0149      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 428         |
# |    ep_rew_mean          | 428         |
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 22          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004192344 |
# |    clip_fraction        | 0.0303      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | -0.00075    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00101     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00143    |
# |    value_loss           | 0.00928     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 438          |
# |    ep_rew_mean          | 438          |
# | time/                   |              |
# |    fps                  | 768          |
# |    iterations           | 23           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0070093395 |
# |    clip_fraction        | 0.0707       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.528       |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0299      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00341     |
# |    value_loss           | 0.00648      |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 447       |
# |    ep_rew_mean          | 447       |
# | time/                   |           |
# |    fps                  | 768       |
# |    iterations           | 24        |
# |    time_elapsed         | 63        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0061852 |
# |    clip_fraction        | 0.0353    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.52     |
# |    explained_variance   | 0.00126   |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00768  |
# |    n_updates            | 280       |
# |    policy_gradient_loss | -0.000877 |
# |    value_loss           | 0.00409   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 455         |
# |    ep_rew_mean          | 455         |
# | time/                   |             |
# |    fps                  | 762         |
# |    iterations           | 25          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.002258256 |
# |    clip_fraction        | 0.019       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.49       |
# |    explained_variance   | 0.00246     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0118      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00144    |
# |    value_loss           | 0.00281     |
# -----------------------------------------

# %%
total_rewards = []
obs, _ = env.reset()
for _ in range(10):
    done = False
    episode_reward = 0
    while not done:
        action, _ = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        episode_reward += reward
        done = terminated or truncated
        if done:
            total_rewards.append(episode_reward)
            obs, _ = env.reset()

print("Episode rewards:", total_rewards)
# Out:
# Episode rewards: [500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0]

# %%
total_rewards = []
obs, _ = env.reset()
for _ in range(10):
    done = False
    episode_reward = 0
    while not done:
        action, _ = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        episode_reward += reward
        done = terminated or truncated
        if done:
            total_rewards.append(episode_reward)
            obs, _ = env.reset()

print("Episode rewards:", total_rewards)
# Out:
# Episode rewards: [500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0]

# %%
model.save("models/ppo_cartpole_v1_maxed")
# Out:
# D:\RL_Projects\venv\Lib\site-packages\stable_baselines3\common\save_util.py:284: UserWarning: Path 'models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
model = PPO.load("models/ppo_cartpole_v1_maxed")

# %%
env = gym.make("LunarLander-v2")
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=50000)
# Out:
# D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\registration.py:512: DeprecationWarning: WARN: The environment LunarLander-v2 is out of date. You should consider upgrading to version `v3`.
#   logger.deprecation(
# ---------------------------------------------------------------------------
# DeprecatedEnv                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 env = gym.make("LunarLander-v2")
#       2 model = PPO("MlpPolicy", env, verbose=1)
#       3 model.learn(total_timesteps=50000)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\registration.py:681, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     678     assert isinstance(id, str)
#     680     # The environment name can include an unloaded module in "module:env_name" style
# --> 681     env_spec = _find_spec(id)
#     683 assert isinstance(env_spec, EnvSpec)
#     685 # Update the env spec kwargs with the `make` kwargs
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\registration.py:526, in _find_spec(env_id)
#     520     logger.warn(
#     521         f"Using the latest versioned environment `{new_env_id}` "
#     522         f"instead of the unversioned environment `{env_name}`."
#     523     )
#     525 if env_spec is None:
# --> 526     _check_version_exists(ns, name, version)
#     527     raise error.Error(
#     528         f"No registered env with id: {env_name}. Did you register it, or import the package that registers it? Use `gymnasium.pprint_registry()` to see all of the registered environments."
#     529     )
#     531 return env_spec
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\registration.py:426, in _check_version_exists(ns, name, version)
#     423     raise error.VersionNotFound(message)
#     425 if latest_spec is not None and version < latest_spec.version:
# --> 426     raise error.DeprecatedEnv(
#     427         f"Environment version v{version} for `{get_env_id(ns, name, None)}` is deprecated. "
#     428         f"Please use `{latest_spec.id}` instead."
#     429     )
#
# DeprecatedEnv: Environment version v2 for `LunarLander` is deprecated. Please use `LunarLander-v3` instead.

# %%
env = gym.make("LunarLander-v2")
# Out:
# ---------------------------------------------------------------------------
# DeprecatedEnv                             Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 env = gym.make("LunarLander-v2")
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\registration.py:681, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     678     assert isinstance(id, str)
#     680     # The environment name can include an unloaded module in "module:env_name" style
# --> 681     env_spec = _find_spec(id)
#     683 assert isinstance(env_spec, EnvSpec)
#     685 # Update the env spec kwargs with the `make` kwargs
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\registration.py:526, in _find_spec(env_id)
#     520     logger.warn(
#     521         f"Using the latest versioned environment `{new_env_id}` "
#     522         f"instead of the unversioned environment `{env_name}`."
#     523     )
#     525 if env_spec is None:
# --> 526     _check_version_exists(ns, name, version)
#     527     raise error.Error(
#     528         f"No registered env with id: {env_name}. Did you register it, or import the package that registers it? Use `gymnasium.pprint_registry()` to see all of the registered environments."
#     529     )
#     531 return env_spec
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\registration.py:426, in _check_version_exists(ns, name, version)
#     423     raise error.VersionNotFound(message)
#     425 if latest_spec is not None and version < latest_spec.version:
# --> 426     raise error.DeprecatedEnv(
#     427         f"Environment version v{version} for `{get_env_id(ns, name, None)}` is deprecated. "
#     428         f"Please use `{latest_spec.id}` instead."
#     429     )
#
# DeprecatedEnv: Environment version v2 for `LunarLander` is deprecated. Please use `LunarLander-v3` instead.

# %%
env = gym.make("LunarLander-v3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\box2d\bipedal_walker.py:15
#      14 try:
# ---> 15     import Box2D
#      16     from Box2D.b2 import (
#      17         circleShape,
#      18         contactListener,
#    (...)     22         revoluteJointDef,
#      23     )
#
# ModuleNotFoundError: No module named 'Box2D'
#
# The above exception was the direct cause of the following exception:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 env = gym.make("LunarLander-v3")
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\registration.py:696, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     693     env_creator = env_spec.entry_point
#     694 else:
#     695     # Assume it's a string
# --> 696     env_creator = load_env_creator(env_spec.entry_point)
#     698 # Determine if to use the rendering
#     699 render_modes: list[str] | None = None
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\registration.py:544, in load_env_creator(name)
#     535 """Loads an environment with name of style ``"(import path):(environment name)"`` and returns the environment creation function, normally the environment class type.
#     536
#     537 Args:
#    (...)    541     The environment constructor for the given environment name.
#     542 """
#     543 mod_name, attr_name = name.split(":")
# --> 544 mod = importlib.import_module(mod_name)
#     545 fn = getattr(mod, attr_name)
#     546 return fn
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1310, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1026, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\box2d\__init__.py:1
# ----> 1 from gymnasium.envs.box2d.bipedal_walker import BipedalWalker, BipedalWalkerHardcore
#       2 from gymnasium.envs.box2d.car_racing import CarRacing
#       3 from gymnasium.envs.box2d.lunar_lander import LunarLander, LunarLanderContinuous
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\box2d\bipedal_walker.py:25
#      16     from Box2D.b2 import (
#      17         circleShape,
#      18         contactListener,
#    (...)     22         revoluteJointDef,
#      23     )
#      24 except ImportError as e:
# ---> 25     raise DependencyNotInstalled(
#      26         'Box2D is not installed, you can install it by run `pip install swig` followed by `pip install "gymnasium[box2d]"`'
#      27     ) from e
#      30 if TYPE_CHECKING:
#      31     import pygame
#
# DependencyNotInstalled: Box2D is not installed, you can install it by run `pip install swig` followed by `pip install "gymnasium[box2d]"`

# %%
import gymnasium as gym

env = gym.make("LunarLander-v3")
obs, _ = env.reset()
print("Environment loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\box2d\bipedal_walker.py:15
#      14 try:
# ---> 15     import Box2D
#      16     from Box2D.b2 import (
#      17         circleShape,
#      18         contactListener,
#    (...)     22         revoluteJointDef,
#      23     )
#
# ModuleNotFoundError: No module named 'Box2D'
#
# The above exception was the direct cause of the following exception:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# Cell In[10], line 3
#       1 import gymnasium as gym
# ----> 3 env = gym.make("LunarLander-v3")
#       4 obs, _ = env.reset()
#       5 print("Environment loaded successfully!")
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\registration.py:696, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     693     env_creator = env_spec.entry_point
#     694 else:
#     695     # Assume it's a string
# --> 696     env_creator = load_env_creator(env_spec.entry_point)
#     698 # Determine if to use the rendering
#     699 render_modes: list[str] | None = None
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\registration.py:544, in load_env_creator(name)
#     535 """Loads an environment with name of style ``"(import path):(environment name)"`` and returns the environment creation function, normally the environment class type.
#     536
#     537 Args:
#    (...)    541     The environment constructor for the given environment name.
#     542 """
#     543 mod_name, attr_name = name.split(":")
# --> 544 mod = importlib.import_module(mod_name)
#     545 fn = getattr(mod, attr_name)
#     546 return fn
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1310, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1026, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\box2d\__init__.py:1
# ----> 1 from gymnasium.envs.box2d.bipedal_walker import BipedalWalker, BipedalWalkerHardcore
#       2 from gymnasium.envs.box2d.car_racing import CarRacing
#       3 from gymnasium.envs.box2d.lunar_lander import LunarLander, LunarLanderContinuous
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\box2d\bipedal_walker.py:25
#      16     from Box2D.b2 import (
#      17         circleShape,
#      18         contactListener,
#    (...)     22         revoluteJointDef,
#      23     )
#      24 except ImportError as e:
# ---> 25     raise DependencyNotInstalled(
#      26         'Box2D is not installed, you can install it by run `pip install swig` followed by `pip install "gymnasium[box2d]"`'
#      27     ) from e
#      30 if TYPE_CHECKING:
#      31     import pygame
#
# DependencyNotInstalled: Box2D is not installed, you can install it by run `pip install swig` followed by `pip install "gymnasium[box2d]"`

# %%
import gymnasium as gym
from stable_baselines3 import PPO

# Create the environment
env = gym.make("MountainCar-v0")

# Initialize the PPO agent
model = PPO("MlpPolicy", env, verbose=1)

# Train the agent
model.learn(total_timesteps=50000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    fps             | 1936     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1284         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0038954113 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00257     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16           |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000941    |
# |    value_loss           | 133          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1130         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0063142665 |
# |    clip_fraction        | 0.00229      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0107      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.2         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 91.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1082         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0020635612 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.00669     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.4         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000182    |
# |    value_loss           | 85.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1049        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010773717 |
# |    clip_fraction        | 0.0286      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00213    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00355    |
# |    value_loss           | 70.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 1041       |
# |    iterations           | 6          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00427249 |
# |    clip_fraction        | 0.00513    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.00274    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9          |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00157   |
# |    value_loss           | 55.3       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1035         |
# |    iterations           | 7            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0012782823 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.00144      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.8          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | 7.29e-05     |
# |    value_loss           | 42.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1029        |
# |    iterations           | 8           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010671139 |
# |    clip_fraction        | 0.0168      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 9.36e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.15        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.000843   |
# |    value_loss           | 31.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1017         |
# |    iterations           | 9            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0002421134 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.00135     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.03         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.000416     |
# |    value_loss           | 21.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1001        |
# |    iterations           | 10          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004771208 |
# |    clip_fraction        | 0.0174      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.00152     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.65        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 14.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1000        |
# |    iterations           | 11          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005796108 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.00307     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.403       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -2.8e-05    |
# |    value_loss           | 9.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1000        |
# |    iterations           | 12          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012816131 |
# |    clip_fraction        | 0.0206      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00122    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.424       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.002      |
# |    value_loss           | 6.23        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 993        |
# |    iterations           | 13         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.00195878 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.1       |
# |    explained_variance   | -0.000395  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.305      |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -8.19e-06  |
# |    value_loss           | 3.98       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 994          |
# |    iterations           | 14           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0014378428 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.000341     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.278        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000187    |
# |    value_loss           | 2.42         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 992         |
# |    iterations           | 15          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010772475 |
# |    clip_fraction        | 0.0261      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.000275    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.169       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00218    |
# |    value_loss           | 1.54        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 992         |
# |    iterations           | 16          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008379518 |
# |    clip_fraction        | 0.0165      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00053    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0738      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00193    |
# |    value_loss           | 0.962       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 993         |
# |    iterations           | 17          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.014055289 |
# |    clip_fraction        | 0.00786     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.000675   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0345      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00133    |
# |    value_loss           | 0.637       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 995         |
# |    iterations           | 18          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010376021 |
# |    clip_fraction        | 0.0247      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 5.47e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0822      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 0.382       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 993        |
# |    iterations           | 19         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01101853 |
# |    clip_fraction        | 0.00962    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 4.75e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0189     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.000537  |
# |    value_loss           | 0.255      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 992         |
# |    iterations           | 20          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007247825 |
# |    clip_fraction        | 0.02        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.00249    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0146      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00161    |
# |    value_loss           | 0.162       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 989          |
# |    iterations           | 21           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0014296914 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.962       |
# |    explained_variance   | -0.00242     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0289       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000571    |
# |    value_loss           | 0.0975       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 981         |
# |    iterations           | 22          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011257422 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | -0.00251    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.019       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00378    |
# |    value_loss           | 0.0697      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 980          |
# |    iterations           | 23           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0094473865 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.813       |
# |    explained_variance   | -0.00272     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0121       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 0.0467       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 979          |
# |    iterations           | 24           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0032780124 |
# |    clip_fraction        | 0.00269      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.764       |
# |    explained_variance   | -0.00183     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.014       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 0.000418     |
# |    value_loss           | 0.0311       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 978          |
# |    iterations           | 25           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0034360741 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.707       |
# |    explained_variance   | -0.00297     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00453      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000308    |
# |    value_loss           | 0.0205       |
# ------------------------------------------

# %%
obs, _ = env.reset()
total_reward = 0
for _ in range(200):
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)
    total_reward += reward
    if terminated or truncated:
        break

print("Total reward:", total_reward)
# Out:
# Total reward: -200.0

# %%
model.learn(total_timesteps=100_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    fps             | 2043     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1335         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0034476982 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.615       |
# |    explained_variance   | -0.00471     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00305     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 0.00928      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1155         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0031123736 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.615       |
# |    explained_variance   | -0.00308     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00835      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 0.00646      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 1099          |
# |    iterations           | 4             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00023801613 |
# |    clip_fraction        | 0.000342      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.585        |
# |    explained_variance   | -0.00413      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00289       |
# |    n_updates            | 280           |
# |    policy_gradient_loss | 0.000522      |
# |    value_loss           | 0.00428       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1086        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004569114 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.526      |
# |    explained_variance   | -0.00411    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00759    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00315    |
# |    value_loss           | 0.00301     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1064         |
# |    iterations           | 6            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0018524607 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | -0.00457     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00059      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 0.00222      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1057         |
# |    iterations           | 7            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0025695874 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | -0.00529     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00725     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 0.00151      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1057         |
# |    iterations           | 8            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0019496382 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.581       |
# |    explained_variance   | -0.00703     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00155      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 0.00107      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1053         |
# |    iterations           | 9            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0025187256 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.547       |
# |    explained_variance   | -0.00803     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00214     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 0.000757     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1052         |
# |    iterations           | 10           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0013437022 |
# |    clip_fraction        | 0.00361      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.522       |
# |    explained_variance   | -0.0109      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0043      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.000218     |
# |    value_loss           | 0.000558     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1045         |
# |    iterations           | 11           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0040477696 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.472       |
# |    explained_variance   | -0.0124      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0131       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 0.000384     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 12          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.001264984 |
# |    clip_fraction        | 0.00474     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.45       |
# |    explained_variance   | -0.0118     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00215     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.000153    |
# |    value_loss           | 0.000277    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1043         |
# |    iterations           | 13           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0017074966 |
# |    clip_fraction        | 0.00933      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.44        |
# |    explained_variance   | -0.00702     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0035      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000538    |
# |    value_loss           | 0.000194     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1042         |
# |    iterations           | 14           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0013387054 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.403       |
# |    explained_variance   | -0.00934     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00804     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 0.000151     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1040         |
# |    iterations           | 15           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0024721622 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.348       |
# |    explained_variance   | -0.0246      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00469     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 0.000105     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1036         |
# |    iterations           | 16           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0013676563 |
# |    clip_fraction        | 0.0085       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.368       |
# |    explained_variance   | -0.0223      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00345      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.000183     |
# |    value_loss           | 7.27e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1035         |
# |    iterations           | 17           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0015064054 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.377       |
# |    explained_variance   | -0.0218      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00526      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00177     |
# |    value_loss           | 5.39e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1035         |
# |    iterations           | 18           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0012467086 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.381       |
# |    explained_variance   | -0.0278      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0013      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 3.98e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1024         |
# |    iterations           | 19           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0024958078 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.324       |
# |    explained_variance   | -0.036       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00274     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 2.67e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1014         |
# |    iterations           | 20           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0013730561 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.296       |
# |    explained_variance   | -0.034       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00206     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000856    |
# |    value_loss           | 1.92e-05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 1007          |
# |    iterations           | 21            |
# |    time_elapsed         | 42            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00068866904 |
# |    clip_fraction        | 0.00815       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.288        |
# |    explained_variance   | -0.0422       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -6.87e-06     |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000414     |
# |    value_loss           | 1.43e-05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 997          |
# |    iterations           | 22           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0009687345 |
# |    clip_fraction        | 0.00576      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.259       |
# |    explained_variance   | -0.0633      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00498     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -7.62e-05    |
# |    value_loss           | 1.06e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 979          |
# |    iterations           | 23           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0008946421 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.221       |
# |    explained_variance   | -0.0735      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00257     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000812    |
# |    value_loss           | 7.33e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 947          |
# |    iterations           | 24           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0006396028 |
# |    clip_fraction        | 0.00586      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.213       |
# |    explained_variance   | -0.0564      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00265      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000193    |
# |    value_loss           | 5.31e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 914          |
# |    iterations           | 25           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0009635261 |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.257       |
# |    explained_variance   | -0.117       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00516      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000368    |
# |    value_loss           | 4.06e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 912          |
# |    iterations           | 26           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0015663849 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.233       |
# |    explained_variance   | -0.102       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000331     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000738    |
# |    value_loss           | 3.05e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 900           |
# |    iterations           | 27            |
# |    time_elapsed         | 61            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00045978106 |
# |    clip_fraction        | 0.00562       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.231        |
# |    explained_variance   | -0.174        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00132       |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.000238     |
# |    value_loss           | 2.12e-06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 890          |
# |    iterations           | 28           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0011494819 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.244       |
# |    explained_variance   | -0.111       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0037       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.000937    |
# |    value_loss           | 1.55e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 869           |
# |    iterations           | 29            |
# |    time_elapsed         | 68            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00034521712 |
# |    clip_fraction        | 0.00356       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.249        |
# |    explained_variance   | -0.14         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000535     |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -4.97e-05     |
# |    value_loss           | 1.17e-06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 863           |
# |    iterations           | 30            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00080733746 |
# |    clip_fraction        | 0.00786       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.26         |
# |    explained_variance   | -0.31         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0127        |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -0.000174     |
# |    value_loss           | 9.95e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 856          |
# |    iterations           | 31           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0006147716 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.282       |
# |    explained_variance   | -0.361       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00305      |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -3.5e-06     |
# |    value_loss           | 7.23e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 32           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0021533493 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.33        |
# |    explained_variance   | -0.401       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00176     |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 6.53e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 839          |
# |    iterations           | 33           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0025644666 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.316       |
# |    explained_variance   | -0.426       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00251     |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.000249    |
# |    value_loss           | 4.48e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 34           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0015747265 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.378       |
# |    explained_variance   | -0.583       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00169     |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 3.28e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 830          |
# |    iterations           | 35           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0005858212 |
# |    clip_fraction        | 0.00342      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.367       |
# |    explained_variance   | -0.661       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000805    |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -8.44e-05    |
# |    value_loss           | 3.18e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 821          |
# |    iterations           | 36           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0025769514 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.424       |
# |    explained_variance   | -0.502       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00449      |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 2.72e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 821          |
# |    iterations           | 37           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0021977676 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.486       |
# |    explained_variance   | -0.783       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00238      |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.000412    |
# |    value_loss           | 1.24e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 819          |
# |    iterations           | 38           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0031024492 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.518       |
# |    explained_variance   | -1.01        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000134    |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 2.33e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 39          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.005990701 |
# |    clip_fraction        | 0.0662      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.6        |
# |    explained_variance   | -0.714      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0105     |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00589    |
# |    value_loss           | 3.2e-07     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 40           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0051772427 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.668       |
# |    explained_variance   | -0.603       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0138      |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 1.67e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 803          |
# |    iterations           | 41           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0063892268 |
# |    clip_fraction        | 0.0531       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.74        |
# |    explained_variance   | -0.972       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0152       |
# |    n_updates            | 650          |
# |    policy_gradient_loss | -0.00541     |
# |    value_loss           | 4.85e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 802         |
# |    iterations           | 42          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.005614103 |
# |    clip_fraction        | 0.0141      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.779      |
# |    explained_variance   | -0.0759     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0112     |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.00327    |
# |    value_loss           | 9.29e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 800          |
# |    iterations           | 43           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0086602345 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.838       |
# |    explained_variance   | -0.434       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0191       |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -0.00427     |
# |    value_loss           | 7.26e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 801          |
# |    iterations           | 44           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0077663525 |
# |    clip_fraction        | 0.0429       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.878       |
# |    explained_variance   | -0.194       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00302      |
# |    n_updates            | 680          |
# |    policy_gradient_loss | -0.00551     |
# |    value_loss           | 7.37e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 800         |
# |    iterations           | 45          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013260692 |
# |    clip_fraction        | 0.00728     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.86       |
# |    explained_variance   | -0.105      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00414     |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.00154    |
# |    value_loss           | 9.39e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 46          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.013134556 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | -0.442      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00588     |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.00611    |
# |    value_loss           | 1.79e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 793         |
# |    iterations           | 47          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.006767677 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | -0.259      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 710         |
# |    policy_gradient_loss | -0.006      |
# |    value_loss           | 5.52e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 48          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.014362073 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | -0.556      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0184     |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.00854    |
# |    value_loss           | 9.02e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 49          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.006966193 |
# |    clip_fraction        | 0.0803      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.578      |
# |    explained_variance   | -0.361      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00609     |
# |    n_updates            | 730         |
# |    policy_gradient_loss | -0.00385    |
# |    value_loss           | 4.95e-07    |
# -----------------------------------------

# %%
model.learn(total_timesteps=100_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    fps             | 2001     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1170        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004045466 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.422      |
# |    explained_variance   | -1.56       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000353    |
# |    n_updates            | 750         |
# |    policy_gradient_loss | -0.00187    |
# |    value_loss           | 1.03e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1058         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0020685168 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.373       |
# |    explained_variance   | -1.43        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00263     |
# |    n_updates            | 760          |
# |    policy_gradient_loss | -0.00134     |
# |    value_loss           | 1.46e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 986         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006455424 |
# |    clip_fraction        | 0.0664      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.315      |
# |    explained_variance   | -1.42       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00905    |
# |    n_updates            | 770         |
# |    policy_gradient_loss | -0.00725    |
# |    value_loss           | 2.07e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 955          |
# |    iterations           | 5            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0019183654 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.285       |
# |    explained_variance   | -0.706       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0097       |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00041     |
# |    value_loss           | 7.63e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 859         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.002956941 |
# |    clip_fraction        | 0.03        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.248      |
# |    explained_variance   | -1.06       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0117     |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.000693   |
# |    value_loss           | 7.25e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 7            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0011754974 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.224       |
# |    explained_variance   | -1.73        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00731     |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 8.4e-07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 834          |
# |    iterations           | 8            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0030096509 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.207       |
# |    explained_variance   | -1.39        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00623      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 2.27e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 9            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0027076858 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.221       |
# |    explained_variance   | -1.31        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0393       |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 5.34e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 835          |
# |    iterations           | 10           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0015137031 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.216       |
# |    explained_variance   | -1.77        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00273     |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 5.18e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 835         |
# |    iterations           | 11          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.004773722 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.247      |
# |    explained_variance   | -1.66       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0193     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.000657   |
# |    value_loss           | 4.01e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 838          |
# |    iterations           | 12           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0021818546 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.215       |
# |    explained_variance   | -2.01        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00254      |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00301     |
# |    value_loss           | 7.47e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 842           |
# |    iterations           | 13            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00028800717 |
# |    clip_fraction        | 0.00713       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.18         |
# |    explained_variance   | -1.57         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00637      |
# |    n_updates            | 860           |
# |    policy_gradient_loss | -0.00014      |
# |    value_loss           | 7.11e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 14           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0009864835 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.2         |
# |    explained_variance   | -1.77        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00859     |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.000602    |
# |    value_loss           | 1.53e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 840          |
# |    iterations           | 15           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0009018076 |
# |    clip_fraction        | 0.00649      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.206       |
# |    explained_variance   | -2.1         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00231      |
# |    n_updates            | 880          |
# |    policy_gradient_loss | 3.07e-05     |
# |    value_loss           | 6.08e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 814          |
# |    iterations           | 16           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0014122829 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.159       |
# |    explained_variance   | -1.98        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00319      |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 2.51e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 815           |
# |    iterations           | 17            |
# |    time_elapsed         | 42            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00054707826 |
# |    clip_fraction        | 0.0041        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.208        |
# |    explained_variance   | -2.17         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00383       |
# |    n_updates            | 900           |
# |    policy_gradient_loss | 0.000363      |
# |    value_loss           | 5.11e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 821          |
# |    iterations           | 18           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0017019804 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.169       |
# |    explained_variance   | -1.91        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00748     |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00556     |
# |    value_loss           | 3.99e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 827          |
# |    iterations           | 19           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0008506686 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.197       |
# |    explained_variance   | -2.22        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00899     |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 4.98e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 831         |
# |    iterations           | 20          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009188542 |
# |    clip_fraction        | 0.0085      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.221      |
# |    explained_variance   | -2.09       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0201     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0041     |
# |    value_loss           | 1.21e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 837          |
# |    iterations           | 21           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0010583687 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.221       |
# |    explained_variance   | -1.67        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00951      |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 4.48e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 22           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0012167296 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.189       |
# |    explained_variance   | -1.82        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0141      |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.000706    |
# |    value_loss           | 2e-07        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 23           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0020606178 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.206       |
# |    explained_variance   | -1.39        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0135       |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 1.98e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 24           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0020087017 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.253       |
# |    explained_variance   | -1.74        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00118      |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 1.09e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 842          |
# |    iterations           | 25           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0023264992 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.227       |
# |    explained_variance   | -2.16        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0177      |
# |    n_updates            | 980          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 1.11e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 846          |
# |    iterations           | 26           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0032965706 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.187       |
# |    explained_variance   | -1.56        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00211     |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 4.36e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 27           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0043698484 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.226       |
# |    explained_variance   | -1.81        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00062      |
# |    n_updates            | 1000         |
# |    policy_gradient_loss | -0.0034      |
# |    value_loss           | 3.01e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 28          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.000998024 |
# |    clip_fraction        | 0.0112      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.205      |
# |    explained_variance   | -1.91       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00609    |
# |    n_updates            | 1010        |
# |    policy_gradient_loss | -0.00236    |
# |    value_loss           | 2.61e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 856          |
# |    iterations           | 29           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0011422372 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.181       |
# |    explained_variance   | -1.64        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0316       |
# |    n_updates            | 1020         |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 2.45e-07     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 859        |
# |    iterations           | 30         |
# |    time_elapsed         | 71         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 3.9601e-05 |
# |    clip_fraction        | 0.00435    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.133     |
# |    explained_variance   | -1.3       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.000322  |
# |    n_updates            | 1030       |
# |    policy_gradient_loss | -0.000389  |
# |    value_loss           | 9.78e-08   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 31           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0025610887 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.231       |
# |    explained_variance   | -1.69        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00747     |
# |    n_updates            | 1040         |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 1.01e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 864          |
# |    iterations           | 32           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0003389604 |
# |    clip_fraction        | 0.00762      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.156       |
# |    explained_variance   | -1.47        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000419    |
# |    n_updates            | 1050         |
# |    policy_gradient_loss | -9.64e-05    |
# |    value_loss           | 2.66e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 865          |
# |    iterations           | 33           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0016431682 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.21        |
# |    explained_variance   | -1.9         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0183       |
# |    n_updates            | 1060         |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 9.65e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 867           |
# |    iterations           | 34            |
# |    time_elapsed         | 80            |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00076384225 |
# |    clip_fraction        | 0.00479       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.172        |
# |    explained_variance   | -1.91         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0142       |
# |    n_updates            | 1070          |
# |    policy_gradient_loss | -0.00152      |
# |    value_loss           | 3.28e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 869          |
# |    iterations           | 35           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0013007903 |
# |    clip_fraction        | 0.0158       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.17        |
# |    explained_variance   | -1.62        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00371      |
# |    n_updates            | 1080         |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 9.32e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 871           |
# |    iterations           | 36            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 0.00028009663 |
# |    clip_fraction        | 0.00635       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.187        |
# |    explained_variance   | -1.82         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00121       |
# |    n_updates            | 1090          |
# |    policy_gradient_loss | -0.00065      |
# |    value_loss           | 8.54e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 873          |
# |    iterations           | 37           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0017963627 |
# |    clip_fraction        | 0.00566      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.136       |
# |    explained_variance   | -1.08        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0144       |
# |    n_updates            | 1100         |
# |    policy_gradient_loss | -0.000162    |
# |    value_loss           | 1.63e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 876          |
# |    iterations           | 38           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0025043893 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.237       |
# |    explained_variance   | -1.19        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00257     |
# |    n_updates            | 1110         |
# |    policy_gradient_loss | -0.000706    |
# |    value_loss           | 4.91e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 878          |
# |    iterations           | 39           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0022361819 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.235       |
# |    explained_variance   | -1.57        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00836     |
# |    n_updates            | 1120         |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 7.53e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 879          |
# |    iterations           | 40           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0046410393 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.274       |
# |    explained_variance   | -1.76        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0231      |
# |    n_updates            | 1130         |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 7.31e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 879           |
# |    iterations           | 41            |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00012723921 |
# |    clip_fraction        | 0.00996       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.198        |
# |    explained_variance   | -1.81         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00567      |
# |    n_updates            | 1140          |
# |    policy_gradient_loss | -0.00066      |
# |    value_loss           | 1.4e-07       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 881          |
# |    iterations           | 42           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0032561938 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.253       |
# |    explained_variance   | -1.8         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00535     |
# |    n_updates            | 1150         |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 2.81e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 882          |
# |    iterations           | 43           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0028420645 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.276       |
# |    explained_variance   | -2           |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0148       |
# |    n_updates            | 1160         |
# |    policy_gradient_loss | -0.000822    |
# |    value_loss           | 2.99e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 884          |
# |    iterations           | 44           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0029209992 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.276       |
# |    explained_variance   | -1.71        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00737     |
# |    n_updates            | 1170         |
# |    policy_gradient_loss | -0.00475     |
# |    value_loss           | 1.66e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 885          |
# |    iterations           | 45           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0011949255 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.318       |
# |    explained_variance   | -1.78        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0277      |
# |    n_updates            | 1180         |
# |    policy_gradient_loss | -0.0041      |
# |    value_loss           | 1.52e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 886          |
# |    iterations           | 46           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0019592873 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.296       |
# |    explained_variance   | -2.04        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0295      |
# |    n_updates            | 1190         |
# |    policy_gradient_loss | -0.00302     |
# |    value_loss           | 1.36e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 887          |
# |    iterations           | 47           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0017233281 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | -2.31        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0168       |
# |    n_updates            | 1200         |
# |    policy_gradient_loss | -0.00431     |
# |    value_loss           | 2.52e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 888          |
# |    iterations           | 48           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0017477246 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.297       |
# |    explained_variance   | -1.93        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000335     |
# |    n_updates            | 1210         |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 3.36e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 890          |
# |    iterations           | 49           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0020471064 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.269       |
# |    explained_variance   | -2.1         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00723     |
# |    n_updates            | 1220         |
# |    policy_gradient_loss | -0.00529     |
# |    value_loss           | 5.25e-07     |
# ------------------------------------------

# %%
obs, _ = env.reset()
total_reward = 0
for _ in range(200):
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)
    total_reward += reward
    if terminated or truncated:
        break

print("Total reward:", total_reward)
# Out:
# Total reward: -200.0

# %%
model.learn(total_timesteps=200_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    fps             | 1822     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1270         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0021577547 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.252       |
# |    explained_variance   | -1.3         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0164      |
# |    n_updates            | 1240         |
# |    policy_gradient_loss | -0.00216     |
# |    value_loss           | 8.07e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1112         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0019788907 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.263       |
# |    explained_variance   | -0.975       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0184       |
# |    n_updates            | 1250         |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 5.66e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1067         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0019986266 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.259       |
# |    explained_variance   | -1.94        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000867     |
# |    n_updates            | 1260         |
# |    policy_gradient_loss | -0.000901    |
# |    value_loss           | 5.88e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1024         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0019699917 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.264       |
# |    explained_variance   | -1.66        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0176      |
# |    n_updates            | 1270         |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 5.36e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1006         |
# |    iterations           | 6            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0030623726 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.261       |
# |    explained_variance   | -1.69        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0245      |
# |    n_updates            | 1280         |
# |    policy_gradient_loss | -0.00347     |
# |    value_loss           | 2.5e-07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1001         |
# |    iterations           | 7            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0039339033 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.287       |
# |    explained_variance   | -1.57        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00472      |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | -0.00831     |
# |    value_loss           | 8.11e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 999          |
# |    iterations           | 8            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0047665215 |
# |    clip_fraction        | 0.0656       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.27        |
# |    explained_variance   | -1.41        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0261       |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | -0.00691     |
# |    value_loss           | 4.92e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 997           |
# |    iterations           | 9             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00090701284 |
# |    clip_fraction        | 0.00386       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.257        |
# |    explained_variance   | -1.33         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0108        |
# |    n_updates            | 1310          |
# |    policy_gradient_loss | 0.000545      |
# |    value_loss           | 8.71e-07      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 997         |
# |    iterations           | 10          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.002096501 |
# |    clip_fraction        | 0.0216      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.263      |
# |    explained_variance   | -1.22       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0186     |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.00109    |
# |    value_loss           | 2.29e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 989          |
# |    iterations           | 11           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0047981264 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.32        |
# |    explained_variance   | -1.62        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0344      |
# |    n_updates            | 1330         |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 7.24e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 981          |
# |    iterations           | 12           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0027844845 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.298       |
# |    explained_variance   | -1.64        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0176      |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | -0.00656     |
# |    value_loss           | 2.34e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 970          |
# |    iterations           | 13           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0005832205 |
# |    clip_fraction        | 0.00913      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.257       |
# |    explained_variance   | -2.04        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000967    |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 1.48e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 958          |
# |    iterations           | 14           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0007479232 |
# |    clip_fraction        | 0.00771      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.24        |
# |    explained_variance   | -1.19        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00614     |
# |    n_updates            | 1360         |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 8.02e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 951          |
# |    iterations           | 15           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0011713896 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.256       |
# |    explained_variance   | -1.19        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00545      |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.00436     |
# |    value_loss           | 1.64e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 948          |
# |    iterations           | 16           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0030620869 |
# |    clip_fraction        | 0.0376       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.28        |
# |    explained_variance   | -0.839       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0144       |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 8.45e-08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 947          |
# |    iterations           | 17           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0011747868 |
# |    clip_fraction        | 0.00776      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.32        |
# |    explained_variance   | -1.64        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.007       |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 8.19e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 946          |
# |    iterations           | 18           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0033965842 |
# |    clip_fraction        | 0.0368       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.31        |
# |    explained_variance   | -1.45        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0185      |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | -0.0057      |
# |    value_loss           | 6.29e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 942           |
# |    iterations           | 19            |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00030046786 |
# |    clip_fraction        | 0.00879       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.312        |
# |    explained_variance   | -1.66         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00472       |
# |    n_updates            | 1410          |
# |    policy_gradient_loss | -0.000564     |
# |    value_loss           | 8.99e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 942          |
# |    iterations           | 20           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0014317576 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.298       |
# |    explained_variance   | -1.69        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00919     |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | -0.000299    |
# |    value_loss           | 1.8e-06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 941          |
# |    iterations           | 21           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0056553353 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.309       |
# |    explained_variance   | -1.35        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0164      |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 1.48e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 941         |
# |    iterations           | 22          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.002209098 |
# |    clip_fraction        | 0.0283      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.316      |
# |    explained_variance   | -0.705      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0727      |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | 0.00099     |
# |    value_loss           | 5.1e-06     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 937           |
# |    iterations           | 23            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00092202506 |
# |    clip_fraction        | 0.0143        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.287        |
# |    explained_variance   | -1.22         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0148       |
# |    n_updates            | 1450          |
# |    policy_gradient_loss | -0.0024       |
# |    value_loss           | 1.1e-07       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 937          |
# |    iterations           | 24           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0028051375 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.326       |
# |    explained_variance   | -0.968       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000952     |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | -0.00327     |
# |    value_loss           | 1.73e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 937          |
# |    iterations           | 25           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0033671418 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.273       |
# |    explained_variance   | -0.473       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00297      |
# |    n_updates            | 1470         |
# |    policy_gradient_loss | 0.000408     |
# |    value_loss           | 3.33e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 937          |
# |    iterations           | 26           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0013013224 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.28        |
# |    explained_variance   | -0.96        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0193       |
# |    n_updates            | 1480         |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 2.62e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 937         |
# |    iterations           | 27          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.001967437 |
# |    clip_fraction        | 0.0271      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.286      |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00925    |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | -0.00216    |
# |    value_loss           | 5.76e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 937         |
# |    iterations           | 28          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.002027759 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.271      |
# |    explained_variance   | -1.62       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00611     |
# |    n_updates            | 1500        |
# |    policy_gradient_loss | 0.000587    |
# |    value_loss           | 3.55e-08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 921          |
# |    iterations           | 29           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0016750777 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.271       |
# |    explained_variance   | 0.651        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00235      |
# |    n_updates            | 1510         |
# |    policy_gradient_loss | -0.00303     |
# |    value_loss           | 2.79e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 30           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0042655915 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.316       |
# |    explained_variance   | -0.541       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00808     |
# |    n_updates            | 1520         |
# |    policy_gradient_loss | -0.000732    |
# |    value_loss           | 3.91e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 918          |
# |    iterations           | 31           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0013433868 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.277       |
# |    explained_variance   | 0.0693       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0132      |
# |    n_updates            | 1530         |
# |    policy_gradient_loss | 0.000162     |
# |    value_loss           | 2.39e-08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 32          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008355298 |
# |    clip_fraction        | 0.0611      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.314      |
# |    explained_variance   | -0.889      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0163     |
# |    n_updates            | 1540        |
# |    policy_gradient_loss | -0.00299    |
# |    value_loss           | 1.93e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 912         |
# |    iterations           | 33          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004033858 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.328      |
# |    explained_variance   | -0.97       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0257      |
# |    n_updates            | 1550        |
# |    policy_gradient_loss | -0.0093     |
# |    value_loss           | 8.26e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 912          |
# |    iterations           | 34           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0016056551 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.237       |
# |    explained_variance   | -0.245       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00935      |
# |    n_updates            | 1560         |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 4.16e-08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 912          |
# |    iterations           | 35           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0019406974 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.231       |
# |    explained_variance   | 0.346        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00793     |
# |    n_updates            | 1570         |
# |    policy_gradient_loss | 0.00132      |
# |    value_loss           | 8.98e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 912          |
# |    iterations           | 36           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0018054934 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | -0.114       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0069       |
# |    n_updates            | 1580         |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 1.25e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 913          |
# |    iterations           | 37           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0008393107 |
# |    clip_fraction        | 0.00659      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.204       |
# |    explained_variance   | -0.163       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000242     |
# |    n_updates            | 1590         |
# |    policy_gradient_loss | -0.000906    |
# |    value_loss           | 7.84e-08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 913          |
# |    iterations           | 38           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0011301043 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.197       |
# |    explained_variance   | 0.67         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00401     |
# |    n_updates            | 1600         |
# |    policy_gradient_loss | -0.00399     |
# |    value_loss           | 3e-06        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 914           |
# |    iterations           | 39            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00047005247 |
# |    clip_fraction        | 0.00806       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.158        |
# |    explained_variance   | 0.43          |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000212     |
# |    n_updates            | 1610          |
# |    policy_gradient_loss | 0.000375      |
# |    value_loss           | 3.15e-07      |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 914        |
# |    iterations           | 40         |
# |    time_elapsed         | 89         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.02399346 |
# |    clip_fraction        | 0.079      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.311     |
# |    explained_variance   | 0.405      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0456    |
# |    n_updates            | 1620       |
# |    policy_gradient_loss | -0.00603   |
# |    value_loss           | 1.91e-07   |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 915           |
# |    iterations           | 41            |
# |    time_elapsed         | 91            |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00041841913 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.286        |
# |    explained_variance   | 0.0025        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 10.6          |
# |    n_updates            | 1630          |
# |    policy_gradient_loss | -0.000549     |
# |    value_loss           | 59.1          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 916           |
# |    iterations           | 42            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00048945844 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.26         |
# |    explained_variance   | 0.664         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 17.7          |
# |    n_updates            | 1640          |
# |    policy_gradient_loss | -0.000179     |
# |    value_loss           | 64.2          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 917          |
# |    iterations           | 43           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0008060399 |
# |    clip_fraction        | 0.00103      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.274       |
# |    explained_variance   | 0.57         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.9         |
# |    n_updates            | 1650         |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 70.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 918          |
# |    iterations           | 44           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0010563646 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.241       |
# |    explained_variance   | -0.532       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.327        |
# |    n_updates            | 1660         |
# |    policy_gradient_loss | -0.00035     |
# |    value_loss           | 1.41         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 918          |
# |    iterations           | 45           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0011590334 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.255       |
# |    explained_variance   | 0.486        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.46         |
# |    n_updates            | 1670         |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 27.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 919          |
# |    iterations           | 46           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0026260144 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.241       |
# |    explained_variance   | 0.152        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0248       |
# |    n_updates            | 1680         |
# |    policy_gradient_loss | 0.000549     |
# |    value_loss           | 0.0308       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 47          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.003006301 |
# |    clip_fraction        | 0.0318      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.254      |
# |    explained_variance   | -0.682      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0587      |
# |    n_updates            | 1690        |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 0.13        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 199           |
# |    ep_rew_mean          | -199          |
# | time/                   |               |
# |    fps                  | 920           |
# |    iterations           | 48            |
# |    time_elapsed         | 106           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00069824816 |
# |    clip_fraction        | 0.0128        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.319        |
# |    explained_variance   | 0.578         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.74          |
# |    n_updates            | 1700          |
# |    policy_gradient_loss | -0.000172     |
# |    value_loss           | 37.1          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 921          |
# |    iterations           | 49           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0008498233 |
# |    clip_fraction        | 0.00737      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.265       |
# |    explained_variance   | -0.283       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00889      |
# |    n_updates            | 1710         |
# |    policy_gradient_loss | -0.000577    |
# |    value_loss           | 0.155        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 50          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.000996561 |
# |    clip_fraction        | 0.00103     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.286      |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.85        |
# |    n_updates            | 1720        |
# |    policy_gradient_loss | -0.000445   |
# |    value_loss           | 44.3        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 921           |
# |    iterations           | 51            |
# |    time_elapsed         | 113           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00069506635 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.305        |
# |    explained_variance   | 0.739         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.13          |
# |    n_updates            | 1730          |
# |    policy_gradient_loss | -9.31e-05     |
# |    value_loss           | 52.3          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 921          |
# |    iterations           | 52           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0021465626 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.25        |
# |    explained_variance   | -0.307       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26         |
# |    n_updates            | 1740         |
# |    policy_gradient_loss | -0.000691    |
# |    value_loss           | 2.63         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 922           |
# |    iterations           | 53            |
# |    time_elapsed         | 117           |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 0.00074633927 |
# |    clip_fraction        | 0.00688       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.244        |
# |    explained_variance   | 0.601         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 32            |
# |    n_updates            | 1750          |
# |    policy_gradient_loss | -0.00101      |
# |    value_loss           | 22.2          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 922          |
# |    iterations           | 54           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0016924741 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.222       |
# |    explained_variance   | 0.677        |
# |    learning_rate        | 0.0003       |
# ...
# | time/                   |              |
# |    fps                  | 919          |
# |    iterations           | 81           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0014910158 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.194       |
# |    explained_variance   | -1.35        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0253       |
# |    n_updates            | 2030         |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 8.64e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 919          |
# |    iterations           | 82           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0014560956 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.217       |
# |    explained_variance   | -1.3         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00645     |
# |    n_updates            | 2040         |
# |    policy_gradient_loss | -0.00043     |
# |    value_loss           | 1.17e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 919         |
# |    iterations           | 83          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.004702693 |
# |    clip_fraction        | 0.0322      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.258      |
# |    explained_variance   | -1.33       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0133     |
# |    n_updates            | 2050        |
# |    policy_gradient_loss | 0.000123    |
# |    value_loss           | 6.82e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 84           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0026742595 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.21        |
# |    explained_variance   | -1.19        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0282      |
# |    n_updates            | 2060         |
# |    policy_gradient_loss | -0.00615     |
# |    value_loss           | 2.12e-05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 920           |
# |    iterations           | 85            |
# |    time_elapsed         | 189           |
# |    total_timesteps      | 174080        |
# | train/                  |               |
# |    approx_kl            | 0.00038588644 |
# |    clip_fraction        | 0.00317       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.192        |
# |    explained_variance   | -1.6          |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00289      |
# |    n_updates            | 2070          |
# |    policy_gradient_loss | 0.000715      |
# |    value_loss           | 5.38e-06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 86           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0033061416 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.224       |
# |    explained_variance   | -1.84        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0101       |
# |    n_updates            | 2080         |
# |    policy_gradient_loss | -0.00578     |
# |    value_loss           | 1.32e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 87           |
# |    time_elapsed         | 193          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0025387635 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.215       |
# |    explained_variance   | -1.48        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0196      |
# |    n_updates            | 2090         |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 4.94e-06     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 920        |
# |    iterations           | 88         |
# |    time_elapsed         | 195        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.00189542 |
# |    clip_fraction        | 0.0137     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.223     |
# |    explained_variance   | -1.77      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0209     |
# |    n_updates            | 2100       |
# |    policy_gradient_loss | -0.000901  |
# |    value_loss           | 5.55e-06   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 89           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0010073795 |
# |    clip_fraction        | 0.00483      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.205       |
# |    explained_variance   | -1.88        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000409    |
# |    n_updates            | 2110         |
# |    policy_gradient_loss | -0.00012     |
# |    value_loss           | 3.88e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 90           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0014932007 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.181       |
# |    explained_variance   | -1.13        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00358      |
# |    n_updates            | 2120         |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 2.96e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 91          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.002840897 |
# |    clip_fraction        | 0.0157      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.214      |
# |    explained_variance   | -1.72       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0232      |
# |    n_updates            | 2130        |
# |    policy_gradient_loss | -4.95e-06   |
# |    value_loss           | 3.14e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 918          |
# |    iterations           | 92           |
# |    time_elapsed         | 205          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0023694166 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.273       |
# |    explained_variance   | -1.99        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0151       |
# |    n_updates            | 2140         |
# |    policy_gradient_loss | -0.000428    |
# |    value_loss           | 3.02e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 916          |
# |    iterations           | 93           |
# |    time_elapsed         | 207          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0028052418 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | -1.7         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0255      |
# |    n_updates            | 2150         |
# |    policy_gradient_loss | -0.00515     |
# |    value_loss           | 7.23e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 915          |
# |    iterations           | 94           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0024779597 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.25        |
# |    explained_variance   | -1.48        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00933     |
# |    n_updates            | 2160         |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 7.54e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 915          |
# |    iterations           | 95           |
# |    time_elapsed         | 212          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0031555875 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.229       |
# |    explained_variance   | -1.85        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.012       |
# |    n_updates            | 2170         |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 7.66e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 96          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.006460068 |
# |    clip_fraction        | 0.0211      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.23       |
# |    explained_variance   | -1.62       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0286      |
# |    n_updates            | 2180        |
# |    policy_gradient_loss | -0.00461    |
# |    value_loss           | 2.01e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 913          |
# |    iterations           | 97           |
# |    time_elapsed         | 217          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0031093697 |
# |    clip_fraction        | 0.0276       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.259       |
# |    explained_variance   | -1.6         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00649     |
# |    n_updates            | 2190         |
# |    policy_gradient_loss | 0.000248     |
# |    value_loss           | 7.48e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 911          |
# |    iterations           | 98           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0009464291 |
# |    clip_fraction        | 0.00596      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.227       |
# |    explained_variance   | -1.65        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00971     |
# |    n_updates            | 2200         |
# |    policy_gradient_loss | -0.000276    |
# |    value_loss           | 3.3e-06      |
# ------------------------------------------

# %%
model.learn(total_timesteps=200_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    fps             | 1930     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 1202          |
# |    iterations           | 2             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00083827216 |
# |    clip_fraction        | 0.0132        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.227        |
# |    explained_variance   | -1.83         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00524       |
# |    n_updates            | 2220          |
# |    policy_gradient_loss | -0.00314      |
# |    value_loss           | 2.67e-06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 1105          |
# |    iterations           | 3             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00097092177 |
# |    clip_fraction        | 0.0112        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.231        |
# |    explained_variance   | -1.52         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0163        |
# |    n_updates            | 2230          |
# |    policy_gradient_loss | -3.32e-05     |
# |    value_loss           | 5.23e-06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1072         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0017588245 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.232       |
# |    explained_variance   | -1.8         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00971     |
# |    n_updates            | 2240         |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 3.95e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1030        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.001373945 |
# |    clip_fraction        | 0.00845     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.237      |
# |    explained_variance   | -1.92       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0091     |
# |    n_updates            | 2250        |
# |    policy_gradient_loss | 0.000405    |
# |    value_loss           | 4e-06       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 993          |
# |    iterations           | 6            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0017051242 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.197       |
# |    explained_variance   | -1.98        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0278      |
# |    n_updates            | 2260         |
# |    policy_gradient_loss | -0.0056      |
# |    value_loss           | 8.5e-07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 975          |
# |    iterations           | 7            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0023264266 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.253       |
# |    explained_variance   | -1.74        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0296      |
# |    n_updates            | 2270         |
# |    policy_gradient_loss | -0.00331     |
# |    value_loss           | 2.93e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 970           |
# |    iterations           | 8             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00096986664 |
# |    clip_fraction        | 0.00918       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.184        |
# |    explained_variance   | -1.57         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00441      |
# |    n_updates            | 2280          |
# |    policy_gradient_loss | 0.000291      |
# |    value_loss           | 5.85e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 919           |
# |    iterations           | 9             |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00036605145 |
# |    clip_fraction        | 0.00308       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.225        |
# |    explained_variance   | -1.66         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000552      |
# |    n_updates            | 2290          |
# |    policy_gradient_loss | -0.000454     |
# |    value_loss           | 1.37e-06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 898          |
# |    iterations           | 10           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0020934409 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.186       |
# |    explained_variance   | -1.52        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.01        |
# |    n_updates            | 2300         |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 4.62e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 887          |
# |    iterations           | 11           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0019175437 |
# |    clip_fraction        | 0.0454       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.268       |
# |    explained_variance   | -1.67        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0047      |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | -0.00406     |
# |    value_loss           | 1.99e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 883          |
# |    iterations           | 12           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0010866395 |
# |    clip_fraction        | 0.00757      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.234       |
# |    explained_variance   | -1.83        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000941     |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -8.54e-05    |
# |    value_loss           | 1.09e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 885          |
# |    iterations           | 13           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0010951451 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.184       |
# |    explained_variance   | -1.46        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0101      |
# |    n_updates            | 2330         |
# |    policy_gradient_loss | -0.00366     |
# |    value_loss           | 1.56e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 880          |
# |    iterations           | 14           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0016422899 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.234       |
# |    explained_variance   | -1.54        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0308       |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | -0.000831    |
# |    value_loss           | 5.44e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 881          |
# |    iterations           | 15           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0006351071 |
# |    clip_fraction        | 0.00654      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.2         |
# |    explained_variance   | -1.45        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00249     |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | -0.000909    |
# |    value_loss           | 7.85e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 884         |
# |    iterations           | 16          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.002778092 |
# |    clip_fraction        | 0.0136      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.219      |
# |    explained_variance   | -1.4        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0183     |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00261    |
# |    value_loss           | 1.26e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 886         |
# |    iterations           | 17          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008311216 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.22       |
# |    explained_variance   | -1.35       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0266     |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.00619    |
# |    value_loss           | 1.89e-07    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 881        |
# |    iterations           | 18         |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00240009 |
# |    clip_fraction        | 0.0308     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.313     |
# |    explained_variance   | -1.14      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0248     |
# |    n_updates            | 2380       |
# |    policy_gradient_loss | -0.00524   |
# |    value_loss           | 1.9e-06    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 883          |
# |    iterations           | 19           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0035637566 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.293       |
# |    explained_variance   | -1.52        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0242      |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.0031      |
# |    value_loss           | 1.18e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 885          |
# |    iterations           | 20           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0038821702 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.347       |
# |    explained_variance   | -1.6         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0221      |
# |    n_updates            | 2400         |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 1.6e-06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 886          |
# |    iterations           | 21           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0018108076 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.301       |
# |    explained_variance   | -1.24        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0175      |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | -0.00514     |
# |    value_loss           | 6e-07        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 883         |
# |    iterations           | 22          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.001943969 |
# |    clip_fraction        | 0.0127      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.32       |
# |    explained_variance   | -1.13       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0359      |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | -0.00101    |
# |    value_loss           | 1.02e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 873         |
# |    iterations           | 23          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006521171 |
# |    clip_fraction        | 0.0442      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.307      |
# |    explained_variance   | -1.09       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.00397    |
# |    value_loss           | 2.52e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 24          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.001416386 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.266      |
# |    explained_variance   | -0.781      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000442   |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.00153    |
# |    value_loss           | 2.59e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 862         |
# |    iterations           | 25          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006410674 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.276      |
# |    explained_variance   | -1.34       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000337    |
# |    n_updates            | 2450        |
# |    policy_gradient_loss | -0.00275    |
# |    value_loss           | 9.06e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 863          |
# |    iterations           | 26           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0021789735 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.268       |
# |    explained_variance   | -1.3         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0092      |
# |    n_updates            | 2460         |
# |    policy_gradient_loss | -0.000537    |
# |    value_loss           | 8.03e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 865          |
# |    iterations           | 27           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0021969592 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.305       |
# |    explained_variance   | -1.71        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0171      |
# |    n_updates            | 2470         |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 1.84e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 866          |
# |    iterations           | 28           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0022064073 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.21        |
# |    explained_variance   | -1.44        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0205      |
# |    n_updates            | 2480         |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 3.44e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 867          |
# |    iterations           | 29           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0031125818 |
# |    clip_fraction        | 0.0388       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.248       |
# |    explained_variance   | -1.83        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.018       |
# |    n_updates            | 2490         |
# |    policy_gradient_loss | -0.00468     |
# |    value_loss           | 1.42e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 870          |
# |    iterations           | 30           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0015062685 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.251       |
# |    explained_variance   | -1.73        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00717     |
# |    n_updates            | 2500         |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 1.78e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 872          |
# |    iterations           | 31           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0007095699 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.188       |
# |    explained_variance   | -1.62        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00089      |
# |    n_updates            | 2510         |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 2.47e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 873         |
# |    iterations           | 32          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.016252454 |
# |    clip_fraction        | 0.0271      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.21       |
# |    explained_variance   | -1.5        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0433     |
# |    n_updates            | 2520        |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 8.75e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 874         |
# |    iterations           | 33          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.003332735 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.277      |
# |    explained_variance   | -1.73       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0351     |
# |    n_updates            | 2530        |
# |    policy_gradient_loss | -0.00714    |
# |    value_loss           | 3.42e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 876          |
# |    iterations           | 34           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0019054227 |
# |    clip_fraction        | 0.0279       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.268       |
# |    explained_variance   | -1.11        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.04        |
# |    n_updates            | 2540         |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 5.95e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 35          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.004150551 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.291      |
# |    explained_variance   | -1.7        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 2550        |
# |    policy_gradient_loss | -0.00468    |
# |    value_loss           | 6.15e-07    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 878           |
# |    iterations           | 36            |
# |    time_elapsed         | 83            |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 0.00047862658 |
# |    clip_fraction        | 0.0126        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.234        |
# |    explained_variance   | -1.07         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000242     |
# |    n_updates            | 2560          |
# |    policy_gradient_loss | -0.00165      |
# |    value_loss           | 1.23e-06      |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 879        |
# |    iterations           | 37         |
# |    time_elapsed         | 86         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00914901 |
# |    clip_fraction        | 0.0293     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.253     |
# |    explained_variance   | -1.28      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0248    |
# |    n_updates            | 2570       |
# |    policy_gradient_loss | -0.00792   |
# |    value_loss           | 2.36e-07   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 879          |
# |    iterations           | 38           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0015088271 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.259       |
# |    explained_variance   | -1.5         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0185       |
# |    n_updates            | 2580         |
# |    policy_gradient_loss | -0.00439     |
# |    value_loss           | 3.38e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 881          |
# |    iterations           | 39           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0012152615 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.253       |
# |    explained_variance   | -1.62        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0133      |
# |    n_updates            | 2590         |
# |    policy_gradient_loss | -0.000559    |
# |    value_loss           | 5.4e-07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 883          |
# |    iterations           | 40           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0007727608 |
# |    clip_fraction        | 0.00845      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.218       |
# |    explained_variance   | -1.73        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000994     |
# |    n_updates            | 2600         |
# |    policy_gradient_loss | -0.00299     |
# |    value_loss           | 3.93e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 882          |
# |    iterations           | 41           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0009300229 |
# |    clip_fraction        | 0.00977      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.24        |
# |    explained_variance   | -1.7         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00451     |
# |    n_updates            | 2610         |
# |    policy_gradient_loss | -0.0025      |
# |    value_loss           | 3.53e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 881          |
# |    iterations           | 42           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0009450146 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.198       |
# |    explained_variance   | -1.08        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.004        |
# |    n_updates            | 2620         |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 2.18e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 883          |
# |    iterations           | 43           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0008302346 |
# |    clip_fraction        | 0.00522      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.214       |
# |    explained_variance   | -1.19        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00611      |
# |    n_updates            | 2630         |
# |    policy_gradient_loss | -0.000404    |
# |    value_loss           | 3.85e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 884          |
# |    iterations           | 44           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0009799054 |
# |    clip_fraction        | 0.00708      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.173       |
# |    explained_variance   | -0.8         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00132     |
# |    n_updates            | 2640         |
# |    policy_gradient_loss | -0.000654    |
# |    value_loss           | 2.88e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 885         |
# |    iterations           | 45          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.005265468 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.206      |
# |    explained_variance   | -0.064      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0279      |
# |    n_updates            | 2650        |
# |    policy_gradient_loss | -0.0065     |
# |    value_loss           | 6.7e-07     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 884          |
# |    iterations           | 46           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0019273828 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.195       |
# |    explained_variance   | -1.16        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000467    |
# |    n_updates            | 2660         |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 1.74e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 879          |
# |    iterations           | 47           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0014259076 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.205       |
# |    explained_variance   | -1.35        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00761      |
# |    n_updates            | 2670         |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 5.44e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 874         |
# |    iterations           | 48          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008203965 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.259      |
# |    explained_variance   | -1.38       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0374     |
# |    n_updates            | 2680        |
# |    policy_gradient_loss | 0.000128    |
# |    value_loss           | 7.54e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 873          |
# |    iterations           | 49           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0010604517 |
# |    clip_fraction        | 0.00864      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.244       |
# |    explained_variance   | -1.37        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0153      |
# |    n_updates            | 2690         |
# |    policy_gradient_loss | -0.0027      |
# |    value_loss           | 3.94e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 871          |
# |    iterations           | 50           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0020284231 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.226       |
# |    explained_variance   | -2.03        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0294      |
# |    n_updates            | 2700         |
# |    policy_gradient_loss | -0.00513     |
# |    value_loss           | 7.5e-07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 870          |
# |    iterations           | 51           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0003119155 |
# |    clip_fraction        | 0.000537     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.241       |
# |    explained_variance   | -1.46        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00413     |
# |    n_updates            | 2710         |
# |    policy_gradient_loss | 0.000777     |
# |    value_loss           | 5.06e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 864          |
# |    iterations           | 52           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0074690487 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.226       |
# |    explained_variance   | -1.3         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0414      |
# |    n_updates            | 2720         |
# |    policy_gradient_loss | -0.00433     |
# |    value_loss           | 1.6e-07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 864          |
# |    iterations           | 53           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0010046503 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.212       |
# |    explained_variance   | -1.95        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00391      |
# |    n_updates            | 2730         |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 1.33e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 856          |
# |    iterations           | 54           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0011663765 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.192       |
# |    explained_variance   | -1.26        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0206       |
# |    n_updates            | 2740         |
# |    policy_gradient_loss | -0.00542     |
# |    value_loss           | 5.05e-07     |
# ------------------------------------------
# ...
# | time/                   |              |
# |    fps                  | 830          |
# |    iterations           | 81           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0013198804 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.196       |
# |    explained_variance   | -1.61        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00867     |
# |    n_updates            | 3010         |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 4.22e-08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 831          |
# |    iterations           | 82           |
# |    time_elapsed         | 201          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0045870133 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.2         |
# |    explained_variance   | -1.55        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00367      |
# |    n_updates            | 3020         |
# |    policy_gradient_loss | -0.00469     |
# |    value_loss           | 2.1e-07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 830          |
# |    iterations           | 83           |
# |    time_elapsed         | 204          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0026322803 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.245       |
# |    explained_variance   | -1.86        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0205       |
# |    n_updates            | 3030         |
# |    policy_gradient_loss | 0.000509     |
# |    value_loss           | 2.31e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 831          |
# |    iterations           | 84           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0035128281 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.244       |
# |    explained_variance   | -1.6         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0101      |
# |    n_updates            | 3040         |
# |    policy_gradient_loss | -0.000318    |
# |    value_loss           | 7.51e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 832          |
# |    iterations           | 85           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0009774963 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | -1.4         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0227       |
# |    n_updates            | 3050         |
# |    policy_gradient_loss | -0.000621    |
# |    value_loss           | 2.55e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 832         |
# |    iterations           | 86          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.012502268 |
# |    clip_fraction        | 0.04        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.27       |
# |    explained_variance   | -1.63       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.049      |
# |    n_updates            | 3060        |
# |    policy_gradient_loss | -0.00708    |
# |    value_loss           | 3.6e-08     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 832          |
# |    iterations           | 87           |
# |    time_elapsed         | 213          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0017747802 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.236       |
# |    explained_variance   | -1.61        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.015       |
# |    n_updates            | 3070         |
# |    policy_gradient_loss | -0.00318     |
# |    value_loss           | 6.32e-08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 831         |
# |    iterations           | 88          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.001957235 |
# |    clip_fraction        | 0.0294      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.283      |
# |    explained_variance   | -1.61       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00056    |
# |    n_updates            | 3080        |
# |    policy_gradient_loss | 0.000614    |
# |    value_loss           | 1.19e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 89          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.009728381 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.357      |
# |    explained_variance   | -1.42       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0103     |
# |    n_updates            | 3090        |
# |    policy_gradient_loss | -0.00467    |
# |    value_loss           | 1.47e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 90          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.003265726 |
# |    clip_fraction        | 0.0365      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.305      |
# |    explained_variance   | -1.04       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00216     |
# |    n_updates            | 3100        |
# |    policy_gradient_loss | -0.00645    |
# |    value_loss           | 8.82e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 91          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.001238181 |
# |    clip_fraction        | 0.00918     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.266      |
# |    explained_variance   | -1.86       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0181     |
# |    n_updates            | 3110        |
# |    policy_gradient_loss | -0.000573   |
# |    value_loss           | 9.68e-08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 830          |
# |    iterations           | 92           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0018306263 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.322       |
# |    explained_variance   | -1.98        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0272      |
# |    n_updates            | 3120         |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 9.34e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 831          |
# |    iterations           | 93           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0016217194 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.267       |
# |    explained_variance   | -1.11        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0183      |
# |    n_updates            | 3130         |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 1.57e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 831          |
# |    iterations           | 94           |
# |    time_elapsed         | 231          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0008948003 |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.249       |
# |    explained_variance   | -1.31        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0128       |
# |    n_updates            | 3140         |
# |    policy_gradient_loss | -0.000678    |
# |    value_loss           | 3e-07        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 832         |
# |    iterations           | 95          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.002016786 |
# |    clip_fraction        | 0.0181      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.251      |
# |    explained_variance   | -1.58       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0288     |
# |    n_updates            | 3150        |
# |    policy_gradient_loss | -0.00251    |
# |    value_loss           | 3.91e-07    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 831           |
# |    iterations           | 96            |
# |    time_elapsed         | 236           |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 0.00023314272 |
# |    clip_fraction        | 0.00659       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.241        |
# |    explained_variance   | -1.44         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00751      |
# |    n_updates            | 3160          |
# |    policy_gradient_loss | -0.000234     |
# |    value_loss           | 1.94e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 830          |
# |    iterations           | 97           |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0038600084 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.246       |
# |    explained_variance   | -1.27        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00304     |
# |    n_updates            | 3170         |
# |    policy_gradient_loss | -0.0049      |
# |    value_loss           | 5.59e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 828          |
# |    iterations           | 98           |
# |    time_elapsed         | 242          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0023232326 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.282       |
# |    explained_variance   | -1.44        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00113      |
# |    n_updates            | 3180         |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 1.34e-06     |
# ------------------------------------------

# %%
rewards = []

for i in range(10):
    model.learn(total_timesteps=20000, reset_num_timesteps=False)
    
    # Evaluate after each chunk
    obs, _ = env.reset()
    total_reward = 0
    for _ in range(200):
        action, _ = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        if terminated or truncated:
            break
    rewards.append(total_reward)
    print(f"Iteration {i+1}, Reward: {total_reward}")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    fps             | 2103     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 202752   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1311         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0021653753 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.277       |
# |    explained_variance   | -1.29        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00665     |
# |    n_updates            | 3200         |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 3.03e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1108        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 206848      |
# | train/                  |             |
# |    approx_kl            | 0.006057239 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.319      |
# |    explained_variance   | -1.7        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0225     |
# |    n_updates            | 3210        |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 1.29e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1052         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 208896       |
# | train/                  |              |
# |    approx_kl            | 0.0031259654 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.216       |
# |    explained_variance   | -1.17        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0227      |
# |    n_updates            | 3220         |
# |    policy_gradient_loss | -0.00276     |
# |    value_loss           | 7.59e-08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1010        |
# |    iterations           | 5           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 210944      |
# | train/                  |             |
# |    approx_kl            | 0.002265077 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.221      |
# |    explained_variance   | -1.56       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0228     |
# |    n_updates            | 3230        |
# |    policy_gradient_loss | -0.00484    |
# |    value_loss           | 6.75e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 983          |
# |    iterations           | 6            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0019995477 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.259       |
# |    explained_variance   | -0.524       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0223      |
# |    n_updates            | 3240         |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 1.25e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 984          |
# |    iterations           | 7            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 215040       |
# | train/                  |              |
# |    approx_kl            | 0.0043323482 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.216       |
# |    explained_variance   | -0.314       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0146      |
# |    n_updates            | 3250         |
# |    policy_gradient_loss | -0.00069     |
# |    value_loss           | 3.43e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 978         |
# |    iterations           | 8           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 217088      |
# | train/                  |             |
# |    approx_kl            | 0.000997762 |
# |    clip_fraction        | 0.00649     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.247      |
# |    explained_variance   | -0.267      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00115    |
# |    n_updates            | 3260        |
# |    policy_gradient_loss | -0.000476   |
# |    value_loss           | 1.72e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 923          |
# |    iterations           | 9            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 219136       |
# | train/                  |              |
# |    approx_kl            | 0.0012862439 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.266       |
# |    explained_variance   | -0.78        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00241      |
# |    n_updates            | 3270         |
# |    policy_gradient_loss | -0.00324     |
# |    value_loss           | 7.02e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 856          |
# |    iterations           | 10           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.0024067499 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.264       |
# |    explained_variance   | -1.16        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0183      |
# |    n_updates            | 3280         |
# |    policy_gradient_loss | -0.00691     |
# |    value_loss           | 3.48e-07     |
# ------------------------------------------
# Iteration 1, Reward: -200.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    fps             | 1273     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 223232   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1024        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 225280      |
# | train/                  |             |
# |    approx_kl            | 0.002707522 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.234      |
# |    explained_variance   | -0.985      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00599    |
# |    n_updates            | 3300        |
# |    policy_gradient_loss | -0.00275    |
# |    value_loss           | 3.63e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 997         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 227328      |
# | train/                  |             |
# |    approx_kl            | 0.005687603 |
# |    clip_fraction        | 0.0292      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.277      |
# |    explained_variance   | -1.58       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.67e-05    |
# |    n_updates            | 3310        |
# |    policy_gradient_loss | -0.00212    |
# |    value_loss           | 1.65e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 975          |
# |    iterations           | 4            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0018984736 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.276       |
# |    explained_variance   | -1.6         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0269      |
# |    n_updates            | 3320         |
# |    policy_gradient_loss | -0.00117     |
# |    value_loss           | 3.09e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 5           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 231424      |
# | train/                  |             |
# |    approx_kl            | 0.001981384 |
# |    clip_fraction        | 0.0113      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.256      |
# |    explained_variance   | -1.14       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00773    |
# |    n_updates            | 3330        |
# |    policy_gradient_loss | -0.00426    |
# |    value_loss           | 9.75e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 6            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 233472       |
# | train/                  |              |
# |    approx_kl            | 0.0012425253 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.254       |
# |    explained_variance   | -1.44        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00124     |
# |    n_updates            | 3340         |
# |    policy_gradient_loss | -0.000733    |
# |    value_loss           | 5e-07        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 920        |
# |    iterations           | 7          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 235520     |
# | train/                  |            |
# |    approx_kl            | 0.00877918 |
# |    clip_fraction        | 0.0704     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.327     |
# |    explained_variance   | -1.55      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0345    |
# |    n_updates            | 3350       |
# |    policy_gradient_loss | -0.0104    |
# |    value_loss           | 7.03e-07   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 916          |
# |    iterations           | 8            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 237568       |
# | train/                  |              |
# |    approx_kl            | 0.0035978248 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.309       |
# |    explained_variance   | -1.2         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0022      |
# |    n_updates            | 3360         |
# |    policy_gradient_loss | -0.00674     |
# |    value_loss           | 1.44e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 906          |
# |    iterations           | 9            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 239616       |
# | train/                  |              |
# |    approx_kl            | 0.0018086346 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | -1.08        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0117       |
# |    n_updates            | 3370         |
# |    policy_gradient_loss | -0.00077     |
# |    value_loss           | 4.31e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 891          |
# |    iterations           | 10           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 241664       |
# | train/                  |              |
# |    approx_kl            | 0.0013430595 |
# |    clip_fraction        | 0.00903      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.185       |
# |    explained_variance   | -1.24        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00972      |
# |    n_updates            | 3380         |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 1.09e-07     |
# ------------------------------------------
# Iteration 2, Reward: -200.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 199      |
# |    ep_rew_mean     | -199     |
# | time/              |          |
# |    fps             | 1158     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 243712   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 972          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0010671457 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.246       |
# |    explained_variance   | -1.83        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00597      |
# |    n_updates            | 3400         |
# |    policy_gradient_loss | -0.000399    |
# |    value_loss           | 2.47e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 3            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 247808       |
# | train/                  |              |
# |    approx_kl            | 0.0018162054 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.199       |
# |    explained_variance   | -1.27        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00918     |
# |    n_updates            | 3410         |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 1.11e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 760          |
# |    iterations           | 4            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 249856       |
# | train/                  |              |
# |    approx_kl            | 0.0009873258 |
# |    clip_fraction        | 0.00991      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.163       |
# |    explained_variance   | -1.21        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00346      |
# |    n_updates            | 3420         |
# |    policy_gradient_loss | 6.49e-05     |
# |    value_loss           | 1.2e-07      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 251904      |
# | train/                  |             |
# |    approx_kl            | 0.011491166 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.166      |
# |    explained_variance   | -2.57       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00644     |
# |    n_updates            | 3430        |
# |    policy_gradient_loss | -0.00373    |
# |    value_loss           | 1.77e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 716          |
# |    iterations           | 6            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 253952       |
# | train/                  |              |
# |    approx_kl            | 0.0029277527 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.214       |
# |    explained_variance   | -1.92        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0011      |
# |    n_updates            | 3440         |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 2.86e-08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 708          |
# |    iterations           | 7            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 256000       |
# | train/                  |              |
# |    approx_kl            | 0.0148760425 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.273       |
# |    explained_variance   | -1.35        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0486      |
# |    n_updates            | 3450         |
# |    policy_gradient_loss | -0.00564     |
# |    value_loss           | 8.99e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 702          |
# |    iterations           | 8            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 258048       |
# | train/                  |              |
# |    approx_kl            | 0.0015645748 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.256       |
# |    explained_variance   | -2.71        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0107       |
# |    n_updates            | 3460         |
# |    policy_gradient_loss | -0.000259    |
# |    value_loss           | 7.41e-08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 687          |
# |    iterations           | 9            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 260096       |
# | train/                  |              |
# |    approx_kl            | 0.0028597473 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.318       |
# |    explained_variance   | -1.13        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00726      |
# |    n_updates            | 3470         |
# |    policy_gradient_loss | -0.00672     |
# |    value_loss           | 1.25e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 652          |
# |    iterations           | 10           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0023208025 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.204       |
# |    explained_variance   | -1.38        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.192        |
# |    n_updates            | 3480         |
# |    policy_gradient_loss | -0.000977    |
# |    value_loss           | 3.63e-07     |
# ------------------------------------------
# Iteration 3, Reward: -200.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 199      |
# |    ep_rew_mean     | -199     |
# | time/              |          |
# |    fps             | 1084     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 264192   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 758         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 266240      |
# | train/                  |             |
# |    approx_kl            | 0.005750607 |
# |    clip_fraction        | 0.0353      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.263      |
# |    explained_variance   | -2.01       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0387      |
# |    n_updates            | 3500        |
# |    policy_gradient_loss | -0.00354    |
# |    value_loss           | 3.56e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 670          |
# |    iterations           | 3            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 268288       |
# | train/                  |              |
# |    approx_kl            | 0.0031849514 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.271       |
# |    explained_variance   | -1.35        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0417       |
# |    n_updates            | 3510         |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 1.83e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 686         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.001909056 |
# |    clip_fraction        | 0.00996     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.345      |
# |    explained_variance   | -2          |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0133      |
# |    n_updates            | 3520        |
# |    policy_gradient_loss | -0.00224    |
# |    value_loss           | 9.28e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.007754985 |
# |    clip_fraction        | 0.0294      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.257      |
# |    explained_variance   | -1.55       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0689      |
# |    n_updates            | 3530        |
# |    policy_gradient_loss | -0.00566    |
# |    value_loss           | 1.39e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 705          |
# |    iterations           | 6            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 274432       |
# | train/                  |              |
# |    approx_kl            | 0.0028068586 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.217       |
# |    explained_variance   | -0.986       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0412       |
# |    n_updates            | 3540         |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 2.23e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 715          |
# |    iterations           | 7            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0027334588 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.276       |
# |    explained_variance   | -1.75        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0123      |
# |    n_updates            | 3550         |
# |    policy_gradient_loss | -0.00657     |
# |    value_loss           | 3.51e-08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 8            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0021176955 |
# |    clip_fraction        | 0.0279       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.319       |
# |    explained_variance   | -1.81        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000262     |
# |    n_updates            | 3560         |
# |    policy_gradient_loss | -0.00593     |
# |    value_loss           | 1.81e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 750          |
# |    iterations           | 9            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 280576       |
# | train/                  |              |
# |    approx_kl            | 0.0014484597 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.235       |
# |    explained_variance   | -0.422       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0239      |
# |    n_updates            | 3570         |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 6.02e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 761           |
# |    iterations           | 10            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 282624        |
# | train/                  |               |
# |    approx_kl            | 0.00015533506 |
# |    clip_fraction        | 0.00591       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.218        |
# |    explained_variance   | -2.7          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00421       |
# |    n_updates            | 3580          |
# |    policy_gradient_loss | -0.000244     |
# |    value_loss           | 1.12e-07      |
# -------------------------------------------
# Iteration 4, Reward: -200.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 199      |
# |    ep_rew_mean     | -199     |
# | time/              |          |
# |    fps             | 1639     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 284672   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 199        |
# |    ep_rew_mean          | -199       |
# | time/                   |            |
# |    fps                  | 1070       |
# |    iterations           | 2          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 286720     |
# | train/                  |            |
# |    approx_kl            | 0.01009554 |
# |    clip_fraction        | 0.0457     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.285     |
# |    explained_variance   | -1.89      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0226    |
# |    n_updates            | 3600       |
# |    policy_gradient_loss | -0.00257   |
# |    value_loss           | 5.42e-08   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 999         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 288768      |
# | train/                  |             |
# |    approx_kl            | 0.006857491 |
# |    clip_fraction        | 0.0507      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.32       |
# |    explained_variance   | -1.09       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.017       |
# |    n_updates            | 3610        |
# |    policy_gradient_loss | -0.000914   |
# |    value_loss           | 3.19e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 926         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.017175235 |
# |    clip_fraction        | 0.0265      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.323      |
# |    explained_variance   | -1.04       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0889      |
# |    n_updates            | 3620        |
# |    policy_gradient_loss | -0.00459    |
# |    value_loss           | 1.61e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 876          |
# |    iterations           | 5            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 292864       |
# | train/                  |              |
# |    approx_kl            | 0.0033695877 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.334       |
# |    explained_variance   | -0.875       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0178       |
# |    n_updates            | 3630         |
# |    policy_gradient_loss | -0.00084     |
# |    value_loss           | 9.12e-08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 887          |
# |    iterations           | 6            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0018998075 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.258       |
# |    explained_variance   | -1.54        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0248      |
# |    n_updates            | 3640         |
# |    policy_gradient_loss | -0.0055      |
# |    value_loss           | 5.49e-08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 879         |
# |    iterations           | 7           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.004802648 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.359      |
# |    explained_variance   | -1.42       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00971    |
# |    n_updates            | 3650        |
# |    policy_gradient_loss | -0.00188    |
# |    value_loss           | 1.3e-06     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 868          |
# |    iterations           | 8            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 299008       |
# | train/                  |              |
# |    approx_kl            | 0.0049746456 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.332       |
# |    explained_variance   | -0.786       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.036        |
# |    n_updates            | 3660         |
# |    policy_gradient_loss | -0.00603     |
# |    value_loss           | 1.77e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 844          |
# |    iterations           | 9            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 301056       |
# | train/                  |              |
# |    approx_kl            | 0.0033329139 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.345       |
# |    explained_variance   | -1.27        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0348       |
# |    n_updates            | 3670         |
# |    policy_gradient_loss | -0.00867     |
# |    value_loss           | 1.88e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 843          |
# |    iterations           | 10           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 303104       |
# | train/                  |              |
# |    approx_kl            | 0.0027772067 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.29        |
# |    explained_variance   | -1.38        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00188     |
# |    n_updates            | 3680         |
# |    policy_gradient_loss | -0.00341     |
# |    value_loss           | 3.68e-07     |
# ------------------------------------------
# Iteration 5, Reward: -200.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 199      |
# |    ep_rew_mean     | -199     |
# | time/              |          |
# |    fps             | 1862     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 305152   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 1080         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 307200       |
# | train/                  |              |
# |    approx_kl            | 0.0010158246 |
# |    clip_fraction        | 0.00742      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.278       |
# |    explained_variance   | -1.24        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00308      |
# |    n_updates            | 3700         |
# |    policy_gradient_loss | 0.000769     |
# |    value_loss           | 2.39e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 923         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 309248      |
# | train/                  |             |
# |    approx_kl            | 0.001361461 |
# |    clip_fraction        | 0.0169      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.312      |
# |    explained_variance   | -1.04       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0179     |
# |    n_updates            | 3710        |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 1.22e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 846          |
# |    iterations           | 4            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0031213644 |
# |    clip_fraction        | 0.0511       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.255       |
# |    explained_variance   | -1.01        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0215       |
# |    n_updates            | 3720         |
# |    policy_gradient_loss | -0.00401     |
# |    value_loss           | 1.07e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 5            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 313344       |
# | train/                  |              |
# |    approx_kl            | 0.0035644316 |
# |    clip_fraction        | 0.0546       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.291       |
# |    explained_variance   | -1.43        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00315      |
# |    n_updates            | 3730         |
# |    policy_gradient_loss | -0.00254     |
# |    value_loss           | 1.19e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 792          |
# |    iterations           | 6            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 315392       |
# | train/                  |              |
# |    approx_kl            | 0.0030891607 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.225       |
# |    explained_variance   | -0.756       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00176      |
# |    n_updates            | 3740         |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 1.77e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 7            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 317440       |
# | train/                  |              |
# |    approx_kl            | 0.0021738638 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.186       |
# |    explained_variance   | -0.897       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0186      |
# |    n_updates            | 3750         |
# |    policy_gradient_loss | -0.00422     |
# |    value_loss           | 1.78e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# ...
# |    entropy_loss         | -0.275      |
# |    explained_variance   | -0.968      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0268     |
# |    n_updates            | 4000        |
# |    policy_gradient_loss | -0.000897   |
# |    value_loss           | 8.48e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.007194334 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.273      |
# |    explained_variance   | -0.728      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0485      |
# |    n_updates            | 4010        |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 1.79e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 858         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.008391447 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.341      |
# |    explained_variance   | -0.713      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00672     |
# |    n_updates            | 4020        |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 6.03e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 824          |
# |    iterations           | 5            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 374784       |
# | train/                  |              |
# |    approx_kl            | 0.0011769924 |
# |    clip_fraction        | 0.00806      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.295       |
# |    explained_variance   | -0.575       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00279      |
# |    n_updates            | 4030         |
# |    policy_gradient_loss | -0.000366    |
# |    value_loss           | 1.58e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 830          |
# |    iterations           | 6            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0030563371 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.335       |
# |    explained_variance   | -1.62        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00565     |
# |    n_updates            | 4040         |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 1.26e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 846          |
# |    iterations           | 7            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 378880       |
# | train/                  |              |
# |    approx_kl            | 0.0022813436 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.22        |
# |    explained_variance   | -0.157       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000572    |
# |    n_updates            | 4050         |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 1.33e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 843          |
# |    iterations           | 8            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 380928       |
# | train/                  |              |
# |    approx_kl            | 0.0038645864 |
# |    clip_fraction        | 0.0216       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.282       |
# |    explained_variance   | -0.684       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0157      |
# |    n_updates            | 4060         |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 6.43e-08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 821          |
# |    iterations           | 9            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 382976       |
# | train/                  |              |
# |    approx_kl            | 0.0044184662 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.332       |
# |    explained_variance   | -1.36        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0367      |
# |    n_updates            | 4070         |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 6.71e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 10           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 385024       |
# | train/                  |              |
# |    approx_kl            | 0.0060058166 |
# |    clip_fraction        | 0.093        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.4         |
# |    explained_variance   | -1.4         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0248      |
# |    n_updates            | 4080         |
# |    policy_gradient_loss | -0.00441     |
# |    value_loss           | 3.1e-07      |
# ------------------------------------------
# Iteration 9, Reward: -200.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 199      |
# |    ep_rew_mean     | -199     |
# | time/              |          |
# |    fps             | 1673     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 387072   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 1119         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 389120       |
# | train/                  |              |
# |    approx_kl            | 0.0053918622 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.291       |
# |    explained_variance   | -0.775       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.027       |
# |    n_updates            | 4100         |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 1.35e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 1010         |
# |    iterations           | 3            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 391168       |
# | train/                  |              |
# |    approx_kl            | 0.0023828377 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.284       |
# |    explained_variance   | -0.677       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0289      |
# |    n_updates            | 4110         |
# |    policy_gradient_loss | -0.00428     |
# |    value_loss           | 7.5e-08      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 957          |
# |    iterations           | 4            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0045755384 |
# |    clip_fraction        | 0.0548       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.351       |
# |    explained_variance   | -0.948       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0269      |
# |    n_updates            | 4120         |
# |    policy_gradient_loss | -0.00259     |
# |    value_loss           | 5.7e-07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 945          |
# |    iterations           | 5            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 395264       |
# | train/                  |              |
# |    approx_kl            | 0.0022125044 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.3         |
# |    explained_variance   | -0.919       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00329     |
# |    n_updates            | 4130         |
# |    policy_gradient_loss | -0.000895    |
# |    value_loss           | 2.44e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 932         |
# |    iterations           | 6           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.002595699 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.256      |
# |    explained_variance   | -0.736      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.015       |
# |    n_updates            | 4140        |
# |    policy_gradient_loss | -0.00152    |
# |    value_loss           | 6.22e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 940         |
# |    iterations           | 7           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.003592988 |
# |    clip_fraction        | 0.034       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.312      |
# |    explained_variance   | -1.52       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0148     |
# |    n_updates            | 4150        |
# |    policy_gradient_loss | -0.00254    |
# |    value_loss           | 2.9e-07     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 946         |
# |    iterations           | 8           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.007191602 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.266      |
# |    explained_variance   | -0.967      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0129      |
# |    n_updates            | 4160        |
# |    policy_gradient_loss | -0.000768   |
# |    value_loss           | 2.2e-06     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 951          |
# |    iterations           | 9            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 403456       |
# | train/                  |              |
# |    approx_kl            | 0.0017096257 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.275       |
# |    explained_variance   | -0.719       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00511      |
# |    n_updates            | 4170         |
# |    policy_gradient_loss | -0.000974    |
# |    value_loss           | 4.3e-08      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 958          |
# |    iterations           | 10           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 405504       |
# | train/                  |              |
# |    approx_kl            | 0.0071467473 |
# |    clip_fraction        | 0.0507       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.283       |
# |    explained_variance   | -1.05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0389      |
# |    n_updates            | 4180         |
# |    policy_gradient_loss | -0.00746     |
# |    value_loss           | 5.22e-08     |
# ------------------------------------------
# Iteration 10, Reward: -200.0

# %%
from stable_baselines3 import PPO

model = PPO(
    "MlpPolicy",
    env,
    ent_coef=0.05,         # Higher entropy = more exploration
    learning_rate=0.0003,
    gamma=0.99,
    gae_lambda=0.95,
    verbose=1
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=200_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    fps             | 1663     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1127        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007356301 |
# |    clip_fraction        | 0.00898     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.00375     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.2        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00287    |
# |    value_loss           | 139         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1102         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0058075367 |
# |    clip_fraction        | 0.00288      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0333      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12           |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 88.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1092         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0110475905 |
# |    clip_fraction        | 0.00693      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.00167     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.5         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 84.2         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 1067       |
# |    iterations           | 5          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00708323 |
# |    clip_fraction        | 0.00239    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | -0.0109    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.6       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00104   |
# |    value_loss           | 69.6       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1031         |
# |    iterations           | 6            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0024946784 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.00191      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.53         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | 7.11e-05     |
# |    value_loss           | 54.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1024        |
# |    iterations           | 7           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006886173 |
# |    clip_fraction        | 0.000977    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.00177     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.16        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00028    |
# |    value_loss           | 41.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1026         |
# |    iterations           | 8            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0036056426 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.000786    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.77         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000359    |
# |    value_loss           | 30.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1029        |
# |    iterations           | 9           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010692365 |
# |    clip_fraction        | 0.00132     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000418   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.03        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00115    |
# |    value_loss           | 21.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1025        |
# |    iterations           | 10          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008618437 |
# |    clip_fraction        | 0.0198      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00123    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.713       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00389    |
# |    value_loss           | 14.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1022        |
# |    iterations           | 11          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009943798 |
# |    clip_fraction        | 0.0131      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.000939   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.449       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 9.29        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1024         |
# |    iterations           | 12           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0006545449 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.000623     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.183        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.00026      |
# |    value_loss           | 6.03         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1026        |
# |    iterations           | 13          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010008866 |
# |    clip_fraction        | 0.00454     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00279     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0103      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.000935   |
# |    value_loss           | 3.68        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1027        |
# |    iterations           | 14          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009636428 |
# |    clip_fraction        | 0.00942     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00278     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.111       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 2.36        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1027         |
# |    iterations           | 15           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0065618614 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.00118     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 1.44         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1025        |
# |    iterations           | 16          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006183238 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -0.00224    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0462      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000621   |
# |    value_loss           | 0.938       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1021         |
# |    iterations           | 17           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0034264373 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000225    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0116       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00037     |
# |    value_loss           | 0.581        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1017         |
# |    iterations           | 18           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0084551815 |
# |    clip_fraction        | 0.00352      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -9.54e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00552     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 0.396        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1011        |
# |    iterations           | 19          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.015212873 |
# |    clip_fraction        | 0.0235      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00268    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0521     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00225    |
# |    value_loss           | 0.233       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 998         |
# |    iterations           | 20          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010487004 |
# |    clip_fraction        | 0.0192      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00189    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.028      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00352    |
# |    value_loss           | 0.164       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 995         |
# |    iterations           | 21          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.011179384 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.000913    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0205     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00346    |
# |    value_loss           | 0.104       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 993        |
# |    iterations           | 22         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01352266 |
# |    clip_fraction        | 0.0165     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | -8.88e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0228    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00377   |
# |    value_loss           | 0.0667     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 992         |
# |    iterations           | 23          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009920511 |
# |    clip_fraction        | 0.00405     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00982     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0373     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00226    |
# |    value_loss           | 0.0425      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 992          |
# |    iterations           | 24           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0035131418 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0037      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0312      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000473    |
# |    value_loss           | 0.0293       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 990         |
# |    iterations           | 25          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006576284 |
# |    clip_fraction        | 0.021       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.00789    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0558     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00267    |
# |    value_loss           | 0.0195      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 989         |
# |    iterations           | 26          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.015481083 |
# |    clip_fraction        | 0.0372      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0055      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0886     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00275    |
# |    value_loss           | 0.0132      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 987         |
# |    iterations           | 27          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009986878 |
# |    clip_fraction        | 0.0182      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00313    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.052      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00222    |
# |    value_loss           | 0.00911     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 987         |
# |    iterations           | 28          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012923774 |
# |    clip_fraction        | 0.0136      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0048     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0585     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00183    |
# |    value_loss           | 0.00608     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 986          |
# |    iterations           | 29           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0037064296 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0086       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0476      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000312    |
# |    value_loss           | 0.00425      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 985         |
# |    iterations           | 30          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.002362716 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0145     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0717     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.000635   |
# |    value_loss           | 0.00302     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 985          |
# |    iterations           | 31           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0060699703 |
# |    clip_fraction        | 0.000537     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0263       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0735      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 0.00217      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 971         |
# |    iterations           | 32          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008420231 |
# |    clip_fraction        | 0.0131      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0133     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0287     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0039     |
# |    value_loss           | 0.00148     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 967         |
# |    iterations           | 33          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.012395909 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.00266    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0376     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00341    |
# |    value_loss           | 0.00105     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 34          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.017579425 |
# |    clip_fraction        | 0.0817      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0134     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.103      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00781    |
# |    value_loss           | 0.000758    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 35          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009308736 |
# |    clip_fraction        | 0.0154      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0163      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0511     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00366    |
# |    value_loss           | 0.000539    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 960          |
# |    iterations           | 36           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0040521743 |
# |    clip_fraction        | 0.00972      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.00519     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0548      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000976    |
# |    value_loss           | 0.000376     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 957          |
# |    iterations           | 37           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0024762934 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.0219       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0587      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000439    |
# |    value_loss           | 0.000264     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 956          |
# |    iterations           | 38           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0111632915 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.0294       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0776      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00226     |
# |    value_loss           | 0.000191     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 956          |
# |    iterations           | 39           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0064131333 |
# |    clip_fraction        | 0.00791      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0649       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0595      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 0.000143     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 956         |
# |    iterations           | 40          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011076975 |
# |    clip_fraction        | 0.0465      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.0677      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.052      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00514    |
# |    value_loss           | 9.87e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 956          |
# |    iterations           | 41           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0071347686 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -0.00778     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0612      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0027      |
# |    value_loss           | 7.45e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 957          |
# |    iterations           | 42           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0090704905 |
# |    clip_fraction        | 0.00229      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.00979      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0641      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000397     |
# |    value_loss           | 5.15e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 957         |
# |    iterations           | 43          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.012722623 |
# |    clip_fraction        | 0.04        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.0659      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0297     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00419    |
# |    value_loss           | 4.02e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 957         |
# |    iterations           | 44          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.005891761 |
# |    clip_fraction        | 0.0364      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | 0.0141      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0476     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00342    |
# |    value_loss           | 2.87e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 958          |
# |    iterations           | 45           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0025799759 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.942       |
# |    explained_variance   | 0.00484      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0414      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.0001       |
# |    value_loss           | 2.15e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 46          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.003974502 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | -0.094      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0473     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00352    |
# |    value_loss           | 1.69e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 958          |
# |    iterations           | 47           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0064883013 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.944       |
# |    explained_variance   | -0.0879      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0703      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 1.24e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 959          |
# |    iterations           | 48           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0044100927 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.97        |
# |    explained_variance   | 0.0188       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0414      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 1.04e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 958          |
# |    iterations           | 49           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0050467253 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.971       |
# |    explained_variance   | 0.0792       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0737      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 6.35e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 959         |
# |    iterations           | 50          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.013761893 |
# |    clip_fraction        | 0.0887      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.898      |
# |    explained_variance   | 0.148       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0772     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00705    |
# |    value_loss           | 4.78e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 960          |
# |    iterations           | 51           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0049921675 |
# |    clip_fraction        | 0.034        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.868       |
# |    explained_variance   | -0.0304      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0495      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00262     |
# |    value_loss           | 4.41e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 960          |
# |    iterations           | 52           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0074501745 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.923       |
# |    explained_variance   | -0.0121      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0326      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 0.000245     |
# |    value_loss           | 2.56e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 961          |
# |    iterations           | 53           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0081196735 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.929       |
# |    explained_variance   | -0.0343      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0616      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 1.89e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 961           |
# |    iterations           | 54            |
# |    time_elapsed         | 115           |
# |    total_timesteps      | 110592        |
# | train/                  |               |
# |    approx_kl            | 0.00034027424 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.919        |
# |    explained_variance   | -0.0909       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0468       |
# |    n_updates            | 530           |
# |    policy_gradient_loss | 0.000514      |
# |    value_loss           | 2.91e-06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 961          |
# |    iterations           | 55           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 112640       |
# ...
# | time/                   |             |
# |    fps                  | 954         |
# |    iterations           | 81          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.003167689 |
# |    clip_fraction        | 0.0145      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.88       |
# |    explained_variance   | 0.0148      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.4        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.000284   |
# |    value_loss           | 25.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 954         |
# |    iterations           | 82          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.003427736 |
# |    clip_fraction        | 0.00981     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.881      |
# |    explained_variance   | -0.912      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0356     |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.00377    |
# |    value_loss           | 0.0126      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 952         |
# |    iterations           | 83          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.011399016 |
# |    clip_fraction        | 0.0296      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.927      |
# |    explained_variance   | 0.687       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.75        |
# |    n_updates            | 820         |
# |    policy_gradient_loss | 0.000785    |
# |    value_loss           | 3.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 952         |
# |    iterations           | 84          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.004052669 |
# |    clip_fraction        | 0.00181     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.959      |
# |    explained_variance   | 0.524       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.62        |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.000797   |
# |    value_loss           | 28.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 953          |
# |    iterations           | 85           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0020437944 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.98        |
# |    explained_variance   | 0.645        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.6         |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.000237    |
# |    value_loss           | 47.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 952          |
# |    iterations           | 86           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0019063379 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.98        |
# |    explained_variance   | 0.592        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.58         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | 3.63e-05     |
# |    value_loss           | 31.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 952         |
# |    iterations           | 87          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.009758801 |
# |    clip_fraction        | 0.046       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.464       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.00138    |
# |    value_loss           | 1.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 952         |
# |    iterations           | 88          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.005609085 |
# |    clip_fraction        | 0.0248      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.983      |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00367    |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00441    |
# |    value_loss           | 0.46        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 952           |
# |    iterations           | 89            |
# |    time_elapsed         | 191           |
# |    total_timesteps      | 182272        |
# | train/                  |               |
# |    approx_kl            | 0.00016028213 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.924        |
# |    explained_variance   | 0.52          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 17.3          |
# |    n_updates            | 880           |
# |    policy_gradient_loss | -0.000709     |
# |    value_loss           | 25.9          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 951          |
# |    iterations           | 90           |
# |    time_elapsed         | 193          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0018588578 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.949       |
# |    explained_variance   | 0.517        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.279        |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.000362    |
# |    value_loss           | 2.73         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 951         |
# |    iterations           | 91          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.002369382 |
# |    clip_fraction        | 0.00112     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.2        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.000317   |
# |    value_loss           | 23.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 951          |
# |    iterations           | 92           |
# |    time_elapsed         | 198          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0013054999 |
# |    clip_fraction        | 0.00518      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.962       |
# |    explained_variance   | 0.697        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.158        |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00021     |
# |    value_loss           | 7.98         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 951          |
# |    iterations           | 93           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0026195422 |
# |    clip_fraction        | 0.0084       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.938       |
# |    explained_variance   | 0.597        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.96         |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.000501    |
# |    value_loss           | 3.38         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 950          |
# |    iterations           | 94           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0022444678 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.963       |
# |    explained_variance   | 0.473        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.296        |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.000396    |
# |    value_loss           | 15.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 949          |
# |    iterations           | 95           |
# |    time_elapsed         | 204          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0015043479 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.929       |
# |    explained_variance   | 0.577        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.2         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | 0.000684     |
# |    value_loss           | 73.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 948          |
# |    iterations           | 96           |
# |    time_elapsed         | 207          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0008302761 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.949       |
# |    explained_variance   | 0.75         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.6         |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 46.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 947          |
# |    iterations           | 97           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0048516993 |
# |    clip_fraction        | 0.00854      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.969       |
# |    explained_variance   | 0.681        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.3         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00164     |
# |    value_loss           | 44.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 946          |
# |    iterations           | 98           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0051387586 |
# |    clip_fraction        | 0.00483      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.943       |
# |    explained_variance   | 0.739        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.3         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0027      |
# |    value_loss           | 44.6         |
# ------------------------------------------

# %%
model.save("models/ppo_mountaincar_baseline")

# %%
import gymnasium as gym
from stable_baselines3 import PPO

env = gym.make("CartPole-v1")
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=100_000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | 21.1     |
# | time/              |          |
# |    fps             | 1898     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.3        |
# |    ep_rew_mean          | 25.3        |
# | time/                   |             |
# |    fps                  | 1286        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009519663 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00156    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.45        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 47.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.2        |
# |    ep_rew_mean          | 35.2        |
# | time/                   |             |
# |    fps                  | 1184        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009360293 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.27        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 33.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.3        |
# |    ep_rew_mean          | 47.3        |
# | time/                   |             |
# |    fps                  | 1143        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009233812 |
# |    clip_fraction        | 0.0855      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 53.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60.7         |
# |    ep_rew_mean          | 60.7         |
# | time/                   |              |
# |    fps                  | 1129         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0067862975 |
# |    clip_fraction        | 0.0694       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.609       |
# |    explained_variance   | 0.32         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.9         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0154      |
# |    value_loss           | 62           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.6        |
# |    ep_rew_mean          | 74.6        |
# | time/                   |             |
# |    fps                  | 1118        |
# |    iterations           | 6           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009842754 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.589      |
# |    explained_variance   | 0.489       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 57.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94           |
# |    ep_rew_mean          | 94           |
# | time/                   |              |
# |    fps                  | 1108         |
# |    iterations           | 7            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0074837725 |
# |    clip_fraction        | 0.0822       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.572       |
# |    explained_variance   | 0.658        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.7         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 45.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 109          |
# |    ep_rew_mean          | 109          |
# | time/                   |              |
# |    fps                  | 1101         |
# |    iterations           | 8            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0051522166 |
# |    clip_fraction        | 0.0598       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.571       |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11           |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0119      |
# |    value_loss           | 35.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | 127         |
# | time/                   |             |
# |    fps                  | 1098        |
# |    iterations           | 9           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008775223 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.582      |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.06        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 22.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 142          |
# |    ep_rew_mean          | 142          |
# | time/                   |              |
# |    fps                  | 1093         |
# |    iterations           | 10           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0042712013 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.567       |
# |    explained_variance   | 0.561        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41           |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00516     |
# |    value_loss           | 62.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 163         |
# |    ep_rew_mean          | 163         |
# | time/                   |             |
# |    fps                  | 1082        |
# |    iterations           | 11          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.003321982 |
# |    clip_fraction        | 0.021       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.557      |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.91        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00483    |
# |    value_loss           | 22          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | 179          |
# | time/                   |              |
# |    fps                  | 1080         |
# |    iterations           | 12           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0053524883 |
# |    clip_fraction        | 0.0599       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.547       |
# |    explained_variance   | 0.857        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.4         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00646     |
# |    value_loss           | 24.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 195          |
# |    ep_rew_mean          | 195          |
# | time/                   |              |
# |    fps                  | 1078         |
# |    iterations           | 13           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0026158202 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.544       |
# |    explained_variance   | 0.473        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.949        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 19.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 214          |
# |    ep_rew_mean          | 214          |
# | time/                   |              |
# |    fps                  | 1077         |
# |    iterations           | 14           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0041983295 |
# |    clip_fraction        | 0.0483       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | -0.0962      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.95         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00498     |
# |    value_loss           | 27.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 230         |
# |    ep_rew_mean          | 230         |
# | time/                   |             |
# |    fps                  | 1076        |
# |    iterations           | 15          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012803201 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.496      |
# |    explained_variance   | 0.0356      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.379       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00432    |
# |    value_loss           | 2.07        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 251          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 1075         |
# |    iterations           | 16           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0024950106 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0968       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000456    |
# |    value_loss           | 1.3          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 269          |
# |    ep_rew_mean          | 269          |
# | time/                   |              |
# |    fps                  | 1061         |
# |    iterations           | 17           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0056363237 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.505       |
# |    explained_variance   | -0.0124      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0831       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 0.824        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 287          |
# |    ep_rew_mean          | 287          |
# | time/                   |              |
# |    fps                  | 1054         |
# |    iterations           | 18           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0044238404 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.497       |
# |    explained_variance   | -0.0405      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0435       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | 3.67e-05     |
# |    value_loss           | 0.513        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 303          |
# |    ep_rew_mean          | 303          |
# | time/                   |              |
# |    fps                  | 1051         |
# |    iterations           | 19           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0019139649 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.52        |
# |    explained_variance   | -0.00768     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00725      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000343    |
# |    value_loss           | 0.341        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 321          |
# |    ep_rew_mean          | 321          |
# | time/                   |              |
# |    fps                  | 1039         |
# |    iterations           | 20           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0028243521 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.523       |
# |    explained_variance   | -0.0174      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0135       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 0.2          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 338          |
# |    ep_rew_mean          | 338          |
# | time/                   |              |
# |    fps                  | 1035         |
# |    iterations           | 21           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0058737635 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.506       |
# |    explained_variance   | -0.016       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0368       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 0.126        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 355          |
# |    ep_rew_mean          | 355          |
# | time/                   |              |
# |    fps                  | 1033         |
# |    iterations           | 22           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0062283217 |
# |    clip_fraction        | 0.0595       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.498       |
# |    explained_variance   | -0.0231      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0185       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00342     |
# |    value_loss           | 0.0801       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 370          |
# |    ep_rew_mean          | 370          |
# | time/                   |              |
# |    fps                  | 1030         |
# |    iterations           | 23           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0055913045 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.503       |
# |    explained_variance   | -0.02        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0124       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 0.0494       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 385         |
# |    ep_rew_mean          | 385         |
# | time/                   |             |
# |    fps                  | 1026        |
# |    iterations           | 24          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.002894461 |
# |    clip_fraction        | 0.0237      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | -0.039      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00549    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00114    |
# |    value_loss           | 0.0329      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 400          |
# | time/                   |              |
# |    fps                  | 1022         |
# |    iterations           | 25           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0063748946 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.53        |
# |    explained_variance   | -0.0226      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00998     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 0.0208       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 417          |
# |    ep_rew_mean          | 417          |
# | time/                   |              |
# |    fps                  | 1018         |
# |    iterations           | 26           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0044604833 |
# |    clip_fraction        | 0.0387       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.505       |
# |    explained_variance   | 0.0444       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00161     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00513     |
# |    value_loss           | 0.0133       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 431          |
# |    ep_rew_mean          | 431          |
# | time/                   |              |
# |    fps                  | 1014         |
# |    iterations           | 27           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0036672265 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.505       |
# |    explained_variance   | 0.0196       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0108      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 0.00874      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 439          |
# |    ep_rew_mean          | 439          |
# | time/                   |              |
# |    fps                  | 1009         |
# |    iterations           | 28           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0033702159 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.493       |
# |    explained_variance   | 0.0176       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00232     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00229     |
# |    value_loss           | 0.0057       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 449         |
# |    ep_rew_mean          | 449         |
# | time/                   |             |
# |    fps                  | 1008        |
# |    iterations           | 29          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.003027705 |
# |    clip_fraction        | 0.0298      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.477      |
# |    explained_variance   | -0.018      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00342    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 0.0038      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 460         |
# |    ep_rew_mean          | 460         |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 30          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009124673 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.483      |
# |    explained_variance   | -0.0249     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000993    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00571    |
# |    value_loss           | 0.00255     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 468          |
# |    ep_rew_mean          | 468          |
# | time/                   |              |
# |    fps                  | 1006         |
# |    iterations           | 31           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0037343313 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.493       |
# |    explained_variance   | -0.000719    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00757      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 0.00173      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 476         |
# |    ep_rew_mean          | 476         |
# | time/                   |             |
# |    fps                  | 1004        |
# |    iterations           | 32          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007595065 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.479      |
# |    explained_variance   | 0.00272     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00239    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 0.00115     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 486          |
# |    ep_rew_mean          | 486          |
# | time/                   |              |
# |    fps                  | 1004         |
# |    iterations           | 33           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0035871426 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.488       |
# |    explained_variance   | -0.00371     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0126       |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00033     |
# |    value_loss           | 0.000797     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 491          |
# |    ep_rew_mean          | 491          |
# | time/                   |              |
# |    fps                  | 1004         |
# |    iterations           | 34           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0040005753 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.462       |
# |    explained_variance   | -0.0316      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00808     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 0.000552     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 493          |
# |    ep_rew_mean          | 493          |
# | time/                   |              |
# |    fps                  | 1004         |
# |    iterations           | 35           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0050202026 |
# |    clip_fraction        | 0.0533       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.453       |
# |    explained_variance   | -0.0487      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0096      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 0.000381     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1003         |
# |    iterations           | 36           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0040325085 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.44        |
# |    explained_variance   | -0.00805     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -8.14e-05    |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00426     |
# |    value_loss           | 0.0003       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 996         |
# |    iterations           | 37          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.007616625 |
# |    clip_fraction        | 0.0908      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.437      |
# |    explained_variance   | -0.0566     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00608    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00322    |
# |    value_loss           | 0.000208    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 994          |
# |    iterations           | 38           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0050763935 |
# |    clip_fraction        | 0.0616       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.442       |
# |    explained_variance   | -0.0654      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0102       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 0.00014      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 500           |
# |    ep_rew_mean          | 500           |
# | time/                   |               |
# |    fps                  | 994           |
# |    iterations           | 39            |
# |    time_elapsed         | 80            |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00023735288 |
# |    clip_fraction        | 0.0172        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.442        |
# |    explained_variance   | -0.0614       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00162       |
# |    n_updates            | 380           |
# |    policy_gradient_loss | 0.000336      |
# |    value_loss           | 9.79e-05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 991          |
# |    iterations           | 40           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0027072313 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.45        |
# |    explained_variance   | -0.19        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00368     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.000444     |
# |    value_loss           | 7.19e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 990          |
# |    iterations           | 41           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0045078797 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.435       |
# |    explained_variance   | -0.15        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00323      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 5.02e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 989         |
# |    iterations           | 42          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.007271073 |
# |    clip_fraction        | 0.0408      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.398      |
# |    explained_variance   | -0.00844    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000179    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00324    |
# |    value_loss           | 3.24e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 987          |
# |    iterations           | 43           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0032185237 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.39        |
# |    explained_variance   | -0.244       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00384      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.000698     |
# |    value_loss           | 2.41e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 986          |
# |    iterations           | 44           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0036320398 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.371       |
# |    explained_variance   | -0.202       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00478     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 1.75e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 986          |
# |    iterations           | 45           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0019469999 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.378       |
# |    explained_variance   | -0.286       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00626     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000281    |
# |    value_loss           | 1.52e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 985          |
# |    iterations           | 46           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0042039296 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.379       |
# |    explained_variance   | -0.35        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000807    |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00259     |
# |    value_loss           | 9.32e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 985         |
# |    iterations           | 47          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.002091954 |
# |    clip_fraction        | 0.0188      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.357      |
# |    explained_variance   | -0.454      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000363    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.000394   |
# |    value_loss           | 7.8e-06     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 984          |
# |    iterations           | 48           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0014613117 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.38        |
# |    explained_variance   | -0.293       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00633     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000366    |
# |    value_loss           | 6.09e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 983          |
# |    iterations           | 49           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0015735566 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.361       |
# |    explained_variance   | -0.639       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00328     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000419    |
# |    value_loss           | 5.15e-06     |
# ------------------------------------------

# %%
obs, _ = env.reset()
total_reward = 0
for _ in range(500):
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)
    total_reward += reward
    if terminated or truncated:
        break

print("Total reward:", total_reward)
# Out:
# Total reward: 500.0

# %%
model.save("models/ppo_cartpole_1M")

# %%
model.save("D:/RL_Projects/models/ppo_cartpole_1M")

# %%
with open("D:/RL_Projects/logs/training_log_cartpole_1M.txt", "w") as f:
    f.write("Final reward: 500.0\nTrained for 1M timesteps\nEnvironment: CartPole-v1\n")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 with open("D:/RL_Projects/logs/training_log_cartpole_1M.txt", "w") as f:
#       2     f.write("Final reward: 500.0\nTrained for 1M timesteps\nEnvironment: CartPole-v1\n")
#
# File D:\RL_Projects\venv\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/RL_Projects/logs/training_log_cartpole_1M.txt'

# %%
import os

# Create the folder if it doesn't exist
os.makedirs("D:/RL_Projects/logs", exist_ok=True)

# Now write the log file
with open("D:/RL_Projects/logs/training_log_cartpole_1M.txt", "w") as f:
    f.write("Final reward: 500.0\nTrained for 1M timesteps\nEnvironment: CartPole-v1\n")

# %%
import gymnasium as gym
import time

env = gym.make("CartPole-v1", render_mode="human")
obs, _ = env.reset()

for _ in range(500):
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)
    time.sleep(0.02)  # Slow down for visibility
    if terminated or truncated:
        break

env.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:258, in CartPoleEnv.render(self)
#     257 try:
# --> 258     import pygame
#     259     from pygame import gfxdraw
#
# ModuleNotFoundError: No module named 'pygame'
#
# The above exception was the direct cause of the following exception:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# Cell In[28], line 5
#       2 import time
#       4 env = gym.make("CartPole-v1", render_mode="human")
# ----> 5 obs, _ = env.reset()
#       7 for _ in range(500):
#       8     action, _ = model.predict(obs)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\wrappers\common.py:146, in TimeLimit.reset(self, seed, options)
#     136 """Resets the environment with :param:`**kwargs` and sets the number of steps elapsed to zero.
#     137
#     138 Args:
#    (...)    143     The reset environment
#     144 """
#     145 self._elapsed_steps = 0
# --> 146 return super().reset(seed=seed, options=options)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\core.py:333, in Wrapper.reset(self, seed, options)
#     329 def reset(
#     330     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     331 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     332     """Uses the :meth:`reset` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 333     return self.env.reset(seed=seed, options=options)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\wrappers\common.py:400, in OrderEnforcing.reset(self, seed, options)
#     398 """Resets the environment with `kwargs`."""
#     399 self._has_reset = True
# --> 400 return super().reset(seed=seed, options=options)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\core.py:333, in Wrapper.reset(self, seed, options)
#     329 def reset(
#     330     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     331 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     332     """Uses the :meth:`reset` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 333     return self.env.reset(seed=seed, options=options)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\wrappers\common.py:293, in PassiveEnvChecker.reset(self, seed, options)
#     291 if self.checked_reset is False:
#     292     self.checked_reset = True
# --> 293     return env_reset_passive_checker(self.env, seed=seed, options=options)
#     294 else:
#     295     return self.env.reset(seed=seed, options=options)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:185, in env_reset_passive_checker(env, **kwargs)
#     180     logger.deprecation(
#     181         "Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information."
#     182     )
#     184 # Checks the result of env.reset with kwargs
# --> 185 result = env.reset(**kwargs)
#     187 if not isinstance(result, tuple):
#     188     logger.warn(
#     189         f"The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `{type(result)}`"
#     190     )
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:244, in CartPoleEnv.reset(self, seed, options)
#     241 self.steps_beyond_terminated = None
#     243 if self.render_mode == "human":
# --> 244     self.render()
#     245 return np.array(self.state, dtype=np.float32), {}
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:261, in CartPoleEnv.render(self)
#     259     from pygame import gfxdraw
#     260 except ImportError as e:
# --> 261     raise DependencyNotInstalled(
#     262         'pygame is not installed, run `pip install "gymnasium[classic-control]"`'
#     263     ) from e
#     265 if self.screen is None:
#     266     pygame.init()
#
# DependencyNotInstalled: pygame is not installed, run `pip install "gymnasium[classic-control]"`

# %%
pip install "gymnasium[classic-control]"
# Out:
# Requirement already satisfied: gymnasium[classic-control] in d:\rl_projects\venv\lib\site-packages (1.2.1)
# Requirement already satisfied: numpy>=1.21.0 in d:\rl_projects\venv\lib\site-packages (from gymnasium[classic-control]) (2.3.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in d:\rl_projects\venv\lib\site-packages (from gymnasium[classic-control]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in d:\rl_projects\venv\lib\site-packages (from gymnasium[classic-control]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in d:\rl_projects\venv\lib\site-packages (from gymnasium[classic-control]) (0.0.4)
# Collecting pygame>=2.1.3 (from gymnasium[classic-control])
#   Using cached pygame-2.6.1-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Using cached pygame-2.6.1-cp313-cp313-win_amd64.whl (10.6 MB)
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gymnasium as gym
import time

env = gym.make("CartPole-v1", render_mode="human")
obs, _ = env.reset()

for _ in range(500):
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)
    time.sleep(0.02)  # Slow down for visibility
    if terminated or truncated:
        break

env.close()
# Out:
# D:\RL_Projects\venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 obs, _ = env.reset()
#       7 for _ in range(500):
# ----> 8     action, _ = model.predict(obs)
#       9     obs, reward, terminated, truncated, info = env.step(action)
#      10     time.sleep(0.02)  # Slow down for visibility
#
# NameError: name 'model' is not defined

# %%
import gymnasium as gym
from stable_baselines3 import PPO

# %%
model = PPO.load("models/ppo_cartpole_1M")

# %%
env = gym.make("CartPole-v1", render_mode="human")

# %%
import time

obs, _ = env.reset()
for _ in range(500):
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)
    time.sleep(0.02)
    if terminated or truncated:
        break

env.close()

# %%
env = gym.make("CartPole-v1", render_mode="human")

# %%
import time

obs, _ = env.reset()
for _ in range(500):
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)
    time.sleep(0.02)  # Slow down for visibility
    if terminated or truncated:
        obs, _ = env.reset()

env.close()

# %%
import time

obs, _ = env.reset()
for _ in range(1000):  # Longer loop
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)
    time.sleep(0.02)
    if terminated or truncated:
        obs, _ = env.reset()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[8], line 3
#       1 import time
# ----> 3 obs, _ = env.reset()
#       4 for _ in range(1000):  # Longer loop
#       5     action, _ = model.predict(obs)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\wrappers\common.py:146, in TimeLimit.reset(self, seed, options)
#     136 """Resets the environment with :param:`**kwargs` and sets the number of steps elapsed to zero.
#     137
#     138 Args:
#    (...)    143     The reset environment
#     144 """
#     145 self._elapsed_steps = 0
# --> 146 return super().reset(seed=seed, options=options)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\core.py:333, in Wrapper.reset(self, seed, options)
#     329 def reset(
#     330     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     331 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     332     """Uses the :meth:`reset` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 333     return self.env.reset(seed=seed, options=options)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\wrappers\common.py:400, in OrderEnforcing.reset(self, seed, options)
#     398 """Resets the environment with `kwargs`."""
#     399 self._has_reset = True
# --> 400 return super().reset(seed=seed, options=options)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\core.py:333, in Wrapper.reset(self, seed, options)
#     329 def reset(
#     330     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     331 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     332     """Uses the :meth:`reset` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 333     return self.env.reset(seed=seed, options=options)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\wrappers\common.py:295, in PassiveEnvChecker.reset(self, seed, options)
#     293     return env_reset_passive_checker(self.env, seed=seed, options=options)
#     294 else:
# --> 295     return self.env.reset(seed=seed, options=options)
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:244, in CartPoleEnv.reset(self, seed, options)
#     241 self.steps_beyond_terminated = None
#     243 if self.render_mode == "human":
# --> 244     self.render()
#     245 return np.array(self.state, dtype=np.float32), {}
#
# File D:\RL_Projects\venv\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:334, in CartPoleEnv.render(self)
#     331 gfxdraw.hline(self.surf, 0, self.screen_width, carty, (0, 0, 0))
#     333 self.surf = pygame.transform.flip(self.surf, False, True)
# --> 334 self.screen.blit(self.surf, (0, 0))
#     335 if self.render_mode == "human":
#     336     pygame.event.pump()
#
# error: display Surface quit

# %%
import gymnasium as gym
import time
from stable_baselines3 import PPO

# Reload model
model = PPO.load("models/ppo_cartpole_1M")

# Create environment
env = gym.make("CartPole-v1", render_mode="human")

# Run multiple episodes
for episode in range(5):
    obs, _ = env.reset()
    for _ in range(500):
        action, _ = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        time.sleep(0.02)
        if terminated or truncated:
            break

env.close()

# %%
import gymnasium as gym
import time
from stable_baselines3 import PPO

# Reload model
model = PPO.load("models/ppo_cartpole_1M")

# Create environment
env = gym.make("CartPole-v1", render_mode="human")

# Run multiple episodes
for episode in range(5):
    obs, _ = env.reset()
    for _ in range(500):
        action, _ = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        time.sleep(0.02)
        if terminated or truncated:
            break

env.close()

# %%
import gymnasium as gym
import time
from stable_baselines3 import PPO

# Reload model
model = PPO.load("models/ppo_cartpole_1M")

# Create environment
env = gym.make("CartPole-v1", render_mode="human")

# Run multiple episodes
for episode in range(5):
    obs, _ = env.reset()
    for _ in range(500):
        action, _ = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        time.sleep(0.02)
        if terminated or truncated:
            break

env.close()

# %%
import gymnasium as gym
import time
from stable_baselines3 import PPO

# Reload model
model = PPO.load("models/ppo_cartpole_1M")

# Create environment
env = gym.make("CartPole-v1", render_mode="human")

# Run multiple episodes
for episode in range(5):
    obs, _ = env.reset()
    for _ in range(500):
        action, _ = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        time.sleep(0.02)
        if terminated or truncated:
            break

env.close()

# %%
import gymnasium as gym
import time
from stable_baselines3 import PPO

# Reload model
model = PPO.load("models/ppo_cartpole_1M")

# Create environment
env = gym.make("CartPole-v1", render_mode="human")

# Run multiple episodes
for episode in range(5):
    obs, _ = env.reset()
    for _ in range(500):
        action, _ = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        time.sleep(0.02)
        if terminated or truncated:
            break

env.close()
